# %%
import pickle
import pandas as pd
import requests
from bs4 import BeautifulSoup
import sys
import os
from collections import defaultdict
import re
import json
from collections import Counter
import dateutil
from dateutil import parser
from collections import defaultdict
from __future__ import division
import datetime
# %pylab inline
from numpy import arange
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def parseint(string):
    string = str(string)
    return int(''.join([x for x in string if x.isdigit()]))

# %%
with open('movie_info_revised.p' ,'r') as picklefile:
    data = pickle.load(picklefile)

# %%
def date_helper(date):
    try:
        date = parser.parse(date)
        return True
    except: 
        pass
    return False

# %%
history_keys_dic = defaultdict(dict)
for key in data.keys():
    if 'artificial intelligence' in data[key]['keywords']:
        if date_helper(data[key]['date']):
            year = parser.parse(data[key]['date']).year
            history_keys_dic['count'][year]= history_keys_dic['count'].get(year, 0) + 1  
history_df = pd.DataFrame.from_dict(history_keys_dic)
start = pd.datetime(1980, 1, 1)
end = pd.datetime(2016, 1, 1)
x = pd.date_range(start, end, freq='A').year
history_df_years = history_df.reindex(x)
history_df = history_df_years.fillna(0)
history_df['rolling mean']=pd.rolling_mean(history_df['count'], 5).shift(+1)
history_df['difference from mean']=history_df['count']/history_df['rolling mean']

# %%
history_keys_dic
# Out:
# defaultdict(<type 'dict'>, {'count': {1974: 1, 1975: 1, 1977: 1, 1979: 2, 1980: 1, 1982: 2, 1983: 1, 1984: 4, 1986: 3, 1990: 2, 1991: 1, 1992: 1, 1993: 1, 1995: 1, 1996: 1, 1997: 1, 1998: 1, 1999: 3, 2001: 1, 2002: 4, 2003: 4, 2004: 1, 2005: 2, 2007: 2, 2008: 3, 2009: 4, 2010: 1, 2011: 1, 2012: 1, 2013: 5, 2014: 1, 2015: 3}})

# %%
history_df
# Out:
#       count  rolling mean  difference from mean
# 1980      1           NaN                   NaN
# 1981      0           NaN                   NaN
# 1982      2           NaN                   NaN
# 1983      1           NaN                   NaN
# 1984      4           NaN                   NaN
# 1985      0           1.6              0.000000
# 1986      3           1.4              2.142857
# 1987      0           2.0              0.000000
# 1988      0           1.6              0.000000
# 1989      0           1.4              0.000000
# 1990      2           0.6              3.333333
# 1991      1           1.0              1.000000
# 1992      1           0.6              1.666667
# 1993      1           0.8              1.250000
# 1994      0           1.0              0.000000
# 1995      1           1.0              1.000000
# 1996      1           0.8              1.250000
# 1997      1           0.8              1.250000
# 1998      1           0.8              1.250000
# 1999      3           0.8              3.750000
# 2000      0           1.4              0.000000
# 2001      1           1.2              0.833333
# 2002      4           1.2              3.333333
# 2003      4           1.8              2.222222
# 2004      1           2.4              0.416667
# 2005      2           2.0              1.000000
# 2006      0           2.4              0.000000
# 2007      2           2.2              0.909091
# 2008      3           1.8              1.666667
# 2009      4           1.6              2.500000
# 2010      1           2.2              0.454545
# 2011      1           2.0              0.500000
# 2012      1           2.2              0.454545
# 2013      5           2.0              2.500000
# 2014      1           2.4              0.416667
# 2015      3           1.8              1.666667

# %%
history_dic = defaultdict(dict)
for key in data.keys():
    if 'War' in data[key]['genre']:
        if date_helper(data[key]['date']):
            year = parser.parse(data[key]['date']).year
            history_dic[year][key]= defaultdict(dict)
            history_dic[year][key]['date']= data[key]['date']
            history_dic[year][key]['screens']= data[key]['screens']
            history_dic[year][key]['opening']= data[key]['opening']
                #space_dic['space'][year].append(key,)

# %%
history_dic
# Out:
# defaultdict(<type 'dict'>, {1973: {'Massacre in Rome': defaultdict(<type 'dict'>, {'date': '24 October 1973', 'screens': 'Error', 'opening': 'N/A'})}, 1975: {'Love and Death': defaultdict(<type 'dict'>, {'date': '10 September 1975', 'screens': 'Error', 'opening': 'N/A'}), 'The Old Gun': defaultdict(<type 'dict'>, {'date': '22 August 1975', 'screens': 'Error', 'opening': 'N/A'})}, 1976: {'Voyage of the Damned': defaultdict(<type 'dict'>, {'date': '22 December 1976', 'screens': 'n/a', 'opening': 'n/a'}), 'Seven Beauties': defaultdict(<type 'dict'>, {'date': '21 January 1976', 'screens': 'Error', 'opening': 'N/A'}), 'General Idi Amin Dada': defaultdict(<type 'dict'>, {'date': '30 August 1976', 'screens': 'Error', 'opening': 'N/A'}), 'Operation: Daybreak': defaultdict(<type 'dict'>, {'date': '27 February 1976', 'screens': 'Error', 'opening': 'N/A'})}, 1977: {'The Hiding Place': defaultdict(<type 'dict'>, {'date': '15 February 1977', 'screens': 'Error', 'opening': 'N/A'}), 'Cross of Iron': defaultdict(<type 'dict'>, {'date': '8 March 1977', 'screens': 'Error', 'opening': 'N/A'}), 'Black and White in Color': defaultdict(<type 'dict'>, {'date': '8 May 1977', 'screens': 'Error', 'opening': 'N/A'}), 'A Bridge Too Far': defaultdict(<type 'dict'>, {'date': '15 June 1977', 'screens': 'n/a', 'opening': 'n/a'}), 'March or Die': defaultdict(<type 'dict'>, {'date': '8 September 1977', 'screens': 'Error', 'opening': 'N/A'})}, 1978: {'Force 10 from Navarone': defaultdict(<type 'dict'>, {'date': '8 December 1978', 'screens': 'Error', 'opening': 'N/A'}), 'Go Tell the Spartans': defaultdict(<type 'dict'>, {'date': '1 September 1978', 'screens': 'Error', 'opening': 'N/A'}), 'Overlord': defaultdict(<type 'dict'>, {'date': '13 March 1978', 'screens': 'Error', 'opening': 'N/A'}), 'The Boys in Company C': defaultdict(<type 'dict'>, {'date': '12 April 1978', 'screens': 'Error', 'opening': 'N/A'}), 'Coming Home': defaultdict(<type 'dict'>, {'date': '15 February 1978', 'screens': 'Error', 'opening': 'N/A'})}, 1979: {'1941': defaultdict(<type 'dict'>, {'date': '14 December 1979', 'screens': '325', 'opening': '$2,701,898'}), 'More American Graffiti': defaultdict(<type 'dict'>, {'date': '3 August 1979', 'screens': 'n/a', 'opening': 'n/a'}), 'The Deer Hunter': defaultdict(<type 'dict'>, {'date': '23 February 1979', 'screens': 'Error', 'opening': 'N/A'}), 'Apocalypse Now': defaultdict(<type 'dict'>, {'date': '15 August 1979', 'screens': '3', 'opening': '$118,558'})}, 1980: {'The Big Red One': defaultdict(<type 'dict'>, {'date': '28 May 1980', 'screens': 'Error', 'opening': 'N/A'}), 'Private Benjamin': defaultdict(<type 'dict'>, {'date': '10 October 1980', 'screens': '763', 'opening': '$4,739,769'}), 'Kagemusha': defaultdict(<type 'dict'>, {'date': '6 October 1980', 'screens': 'Error', 'opening': 'N/A'}), 'Breaker Morant': defaultdict(<type 'dict'>, {'date': '3 July 1980', 'screens': 'Error', 'opening': 'N/A'})}, 1981: {'Eye of the Needle': defaultdict(<type 'dict'>, {'date': '24 July 1981', 'screens': 'n/a', 'opening': 'n/a'}), 'The Sea Wolves': defaultdict(<type 'dict'>, {'date': '5 June 1981', 'screens': 'n/a', 'opening': 'n/a'}), 'Stripes': defaultdict(<type 'dict'>, {'date': '26 June 1981', 'screens': '1,074', 'opening': '$6,130,197'})}, 1982: {'Inchon': defaultdict(<type 'dict'>, {'date': '17 September 1982', 'screens': '1,291', 'opening': '$2,326,112'}), 'Monsignor': defaultdict(<type 'dict'>, {'date': '22 October 1982', 'screens': '857', 'opening': '$3,631,834'}), 'Das Boot': defaultdict(<type 'dict'>, {'date': '10 February 1982', 'screens': '2', 'opening': '$26,994'})}, 1983: {'Under Fire': defaultdict(<type 'dict'>, {'date': '21 October 1983', 'screens': '816', 'opening': '$1,837,768'}), 'Merry Christmas Mr. Lawrence': defaultdict(<type 'dict'>, {'date': '2 September 1983', 'screens': 'Error', 'opening': 'N/A'})}, 1984: {'Red Dawn': defaultdict(<type 'dict'>, {'date': '10 August 1984', 'screens': '1,822', 'opening': '$8,230,381'}), "The Razor's Edge": ...

# %%
def makedf(genre):
    frames = []
    years = []
    for year, movies in genre.items():
        years.append(year)
        frames.append(pd.DataFrame.from_dict(movies, orient='index'))
    genre = pd.concat(frames, keys=years)
    genre = genre[genre.screens != 'N/A']
    genre = genre[genre.screens != 'n/a']
    genre = genre[genre.screens != 'Error']
    genre = genre[genre.opening != 'N/A']
    genre = genre[genre.screens != '']
    genre = genre[genre.opening != '']
    genre = genre[genre.opening != 'n/a']
    genre = genre[genre.opening != 'Error']
    genre['opening'] = genre['opening'].map(lambda x: parseint(x))
    genre['screens'] = genre['screens'].map(lambda x: parseint(x))
    genre['date'] = genre['date'].map(lambda x: parser.parse(x))
    genre['normalized_opening']= genre['opening']/genre['screens']
    genre = genre[genre.normalized_opening < 20000]
    return genre

# %%
genre=makedf(history_dic)
pd.set_option('display.max_rows', 1000)
genre1 = genre[genre.screens > 50]
genre1 = genre1.reset_index()
genre1
# Out:
#     level_0                                         level_1       date  \
# 0      1979                                            1941 1979-12-14
# 1      1980                                Private Benjamin 1980-10-10
# 2      1981                                         Stripes 1981-06-26
# 3      1982                                          Inchon 1982-09-17
# 4      1982                                       Monsignor 1982-10-22
# 5      1983                                      Under Fire 1983-10-21
# 6      1984                                    Best Defense 1984-07-20
# 7      1984                                        Red Dawn 1984-08-10
# 8      1984                                The Razor's Edge 1984-10-19
# 9      1986                                      Iron Eagle 1986-01-17
# 10     1986                                     Sky Bandits 1986-10-31
# 11     1987                               Empire of the Sun 1987-12-25
# 12     1987                               Full Metal Jacket 1987-07-10
# 13     1987                                Gardens of Stone 1987-05-08
# 14     1988                                            1969 1988-11-18
# 15     1988                                      Off Limits 1988-03-11
# 16     1989                               Casualties of War 1989-08-18
# 17     1990                                          Havana 1990-12-12
# 18     1990                                   Memphis Belle 1990-10-12
# 19     1991                          Flight of the Intruder 1991-01-18
# 20     1993                                      Gettysburg 1993-10-08
# 21     1994                                 In the Army Now 1994-08-12
# 22     1998                             Saving Private Ryan 1998-07-24
# 23     1999                                  Jakob the Liar 1999-09-24
# 24     1999                              Tea with Mussolini 1999-05-14
# 25     1999                               The Thin Red Line 1999-01-15
# 26     2000                             Rules of Engagement 2000-04-07
# 27     2000                                           U-571 2000-04-21
# 28     2001                              Behind Enemy Lines 2001-11-30
# 29     2002                              Harrison's Flowers 2002-03-15
# 30     2002                                      Hart's War 2002-02-15
# 31     2002                                     Windtalkers 2002-06-14
# 32     2003                               Gods and Generals 2003-02-21
# 33     2003                                     The Pianist 2003-03-28
# 34     2004                                       The Alamo 2004-04-09
# 35     2005                                         Jarhead 2005-11-04
# 36     2005                                  The Great Raid 2005-08-12
# 37     2006                            Flags of Our Fathers 2006-10-20
# 38     2007                                 Lions for Lambs 2007-11-09
# 39     2008                                           Rambo 2008-01-25
# 40     2008                                       Stop-Loss 2008-03-28
# 41     2008                                  The Lucky Ones 2008-09-26
# 42     2008                                        Valkyrie 2008-12-25
# 43     2009                            Inglourious Basterds 2009-08-21
# 44     2009                      The Men Who Stare at Goats 2009-11-06
# 45     2010                                       Dear John 2010-02-05
# 46     2011                                There Be Dragons 2011-03-25
# 47     2011                                       War Horse 2011-12-25
# 48     2012                                    Act of Valor 2012-02-24
# 49     2012  For Greater Glory: The True Story of Cristiada 2012-06-01
#
#     screens   opening  normalized_opening
# 0       325   2701898         8313.532308
# 1       763   4739769         6212.017038
# 2      1074   6130197         5707.818436
# 3      1291   2326112         1801.790860
# 4       857   3631834         4237.845974
# 5       816   1837768         2252.166667
# 6      1425   7872297         5524.418947
# 7      1822   8230381         4517.223381
# 8      1036   2411311         2327.520270
# 9      1080   6104754         5652.550000
# 10     1335   1468500         1100.000000
# 11      225   1314509         5842.262222
# 12      215   2217307        10313.055814
# 13      612   1645588         2688.869281
# 14      520   1709120         3286.769231
# 15     1366   2796111         2046.933382
# 16     1487   5201261         3497.821789
# 17      824   2175360         2640.000000
# 18     1087   5026846         4624.513339
# 19     1489   5725133         3844.951645
# 20      124    913617         7367.879032
# 21     1444   6367194         4409.414127
# 22     2463  30576104        12414.171336
# 23     1200   2056647         1713.872500
# 24      270   1633183         6048.825926
# 25     1528  11362226         7436.011780
# 26     3155  15011181         4757.902060
# 27     2583  19553310         7570.000000
# 28     2770  18736133         6763.946931
# 29      398    867635         2179.987437
# 30     2459   7771753         3160.533957
# 31     2898  14520412         5010.494134
# 32     1533   4675246         3049.736464
# 33      773   2456117         3177.382924
# 34     2609   9124701         3497.394021
# 35     2411  27726210        11499.879718
# 36      819   3376009         4122.111111
# 37     1876  10245190         5461.188699
# 38     2215   6702434         3025.929571
# 39     2751  18203876         6617.185024
# 40     1291   4555117         3528.363284
# 41      425    183088          430.795294
# 42     2711  21027007         7756.181114
# 43     3165  38054676        12023.594313
# 44     2443  12706654         5201.250102
# 45     2969  30468614        10262.247895
# 46      259    705537         2724.081081
# 47     2376   7515402         3163.047980
# 48     3039  24476632         8054.173083
# 49      757   1885608         2490.895641

# %%
trend = genre1[29:33]

trend
# Out:
#     level_0             level_1       date  screens   opening  \
# 29     2002  Harrison's Flowers 2002-03-15      398    867635
# 30     2002          Hart's War 2002-02-15     2459   7771753
# 31     2002         Windtalkers 2002-06-14     2898  14520412
# 32     2003   Gods and Generals 2003-02-21     1533   4675246
#
#     normalized_opening
# 29         2179.987437
# 30         3160.533957
# 31         5010.494134
# 32         3049.736464

# %%
figure(figsize=(13,15))
trend = trend.sort(['date'])
plt.plot(trend['date'], trend['normalized_opening'])

# %%
trend['time_delta']=trend['date'].apply(lambda x: str(x - parser.parse('2000-01-01')))
trend['time_delta_num'] = trend['time_delta'].str.replace(r'days[\s\S]+', '').apply(lambda x: int(x))

def sort_season(x):
    if x in [11, 12, 1]:
        return 'Winter'
    if x in [5, 6, 7, 8]:
        return 'Summer'
    if x in [9, 10,]:
        return 'Fall'
    if x in [2, 3, 4,]:
        return 'Spring'

trend['season']=trend['date'].apply(lambda x: sort_season(x.month))
from patsy import dmatrices
from patsy import dmatrix
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression
#plot_data = trend
y, X = dmatrices('normalized_opening ~ time_delta_num + season ', data = trend, return_type= 'dataframe')
model = sm.OLS(y, X)
fitted = model.fit()
plot(X['time_delta_num'], y, 'go')
plot(X['time_delta_num'], fitted.fittedvalues, 'b')

# %%
model.fit().summary()
# Out:
# /Users/David/anaconda/lib/python2.7/site-packages/scipy/stats/stats.py:1233: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=16
#   int(n))
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     normalized_opening   R-squared:                       0.416
# Model:                            OLS   Adj. R-squared:                  0.204
# Method:                 Least Squares   F-statistic:                     1.962
# Date:                Thu, 08 Oct 2015   Prob (F-statistic):              0.170
# Time:                        19:11:19   Log-Likelihood:                -143.65
# No. Observations:                  16   AIC:                             297.3
# Df Residuals:                      11   BIC:                             301.2
# Df Model:                           4
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------
# Intercept         5702.4892   2626.483      2.171      0.053       -78.360  1.15e+04
# season[T.Spring]  -782.5719   2226.047     -0.352      0.732     -5682.068  4116.925
# season[T.Summer]   294.2776   2516.181      0.117      0.909     -5243.800  5832.356
# season[T.Winter]  3374.5270   2062.755      1.636      0.130     -1165.567  7914.621
# time_delta_num      -0.9715      0.724     -1.342      0.207        -2.565     0.622
# ==============================================================================
# Omnibus:                        1.918   Durbin-Watson:                   1.960
# Prob(Omnibus):                  0.383   Jarque-Bera (JB):                0.943
# Skew:                           0.595   Prob(JB):                        0.624
# Kurtosis:                       3.013   Cond. No.                     1.40e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.4e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
trend = trend.reset_index()
with open('romance.p', 'w') as picklefile:
    pickle.dump(trend, picklefile)
