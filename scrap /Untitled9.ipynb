# %%
for i in range(1,10):
    print i
    print 'outer'
    for n in range(50,60):
        print n
        print 'inner'
        if i == 3:
            break
# Out:
# 1
# outer
# 50
# inner
# 51
# inner
# 52
# inner
# 53
# inner
# 54
# inner
# 55
# inner
# 56
# inner
# 57
# inner
# 58
# inner
# 59
# inner
# 2
# outer
# 50
# inner
# 51
# inner
# 52
# inner
# 53
# inner
# 54
# inner
# 55
# inner
# 56
# inner
# 57
# inner
# 58
# inner
# 59
# inner
# 3
# outer
# 50
# inner
# 4
# outer
# 50
# inner
# 51
# inner
# 52
# inner
# 53
# inner
# 54
# inner
# 55
# inner
# 56
# inner
# 57
# inner
# 58
# inner
# 59
# inner
# 5
# outer
# 50
# inner
# 51
# inner
# 52
# inner
# 53
# inner
# 54
# inner
# 55
# inner
# 56
# inner
# 57
# inner
# 58
# inner
# 59
# inner
# 6
# outer
# 50
# inner
# 51
# inner
# 52
# inner
# 53
# inner
# 54
# inner
# 55
# inner
# 56
# inner
# 57
# inner
# 58
# inner
# 59
# inner
# 7
# outer
# 50
# inner
# 51
# inner
# 52
# inner
# 53
# inner
# 54
# inner
# 55
# inner
# 56
# inner
# 57
# inner
# 58
# inner
# 59
# inner
# 8
# outer
# 50
# inner
# 51
# inner
# 52
# inner
# 53
# inner
# 54
# inner
# 55
# inner
# 56
# inner
# 57
# inner
# 58
# ...
