# %%
import pickle
import pandas as pd
import requests
from bs4 import BeautifulSoup
import sys

# %%
with open('movie_data_py2.pkl', 'rb') as picklefile:
    movie_list = pickle.load(picklefile)

# %%
page
# Out:
# [[u'Inception',
#   u'(2010)',
#   u'/title/tt1375666/',
#   u'Users rated this 8.8/10 (1,303,923 votes) - click stars to rate',
#   u'8.8',
#   u'A thief who steals corporate secrets through use of dream-sharing technology is given the inverse task of planting an idea into the mind of a CEO.',
#   u'Christopher Nolan',
#   u'Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen Page',
#   u'Action | Mystery | Sci-Fi | Thriller',
#   u'PG_13',
#   u'148 mins.'],
#  [u'Insidious',
#   u'(2010)',
#   u'/title/tt1591095/',
#   u'Users rated this 6.8/10 (179,608 votes) - click stars to rate',
#   u'6.8',
#   u'A family looks to prevent evil spirits from trapping their comatose child in a realm called The Further.',
#   u'James Wan',
#   u'Patrick Wilson, Rose Byrne, Ty Simpkins',
#   u'Drama | Horror | Mystery | Thriller',
#   u'PG_13',
#   u'103 mins.'],
#  [u'Shutter Island',
#   u'(2010)',
#   u'/title/tt1130884/',
#   u'Users rated this 8.1/10 (688,968 votes) - click stars to rate',
#   u'8.1',
#   u'A U.S Marshal investigates the disappearance of a murderess who escaped from a hospital for the criminally insane.',
#   u'Martin Scorsese',
#   u'Leonardo DiCaprio, Emily Mortimer, Mark Ruffalo',
#   u'Mystery | Thriller',
#   u'R',
#   u'138 mins.'],
#  [u'Scott Pilgrim vs. the World',
#   u'(2010)',
#   u'/title/tt0446029/',
#   u'Users rated this 7.5/10 (250,459 votes) - click stars to rate',
#   u'7.5',
#   u"Scott Pilgrim must defeat his new girlfriend's seven evil exes in order to win her heart.",
#   u'Edgar Wright',
#   u'Michael Cera, Mary Elizabeth Winstead, Kieran Culkin',
#   u'Action | Comedy | Fantasy | Romance',
#   u'PG_13',
#   u'112 mins.'],
#  [u'Despicable Me',
#   u'(2010)',
#   u'/title/tt1323594/',
#   u'Users rated this 7.7/10 (345,095 votes) - click stars to rate',
#   u'7.7',
#   u'When a criminal mastermind uses a trio of orphan girls as pawns for a grand scheme, he finds their love is profoundly changing him for the better.',
#   u'Pierre Coffin, Chris Renaud',
#   u'Steve Carell, Jason Segel, Russell Brand',
#   u'Animation | Comedy | Family',
#   u'PG',
#   u'95 mins.'],
#  [u'Easy A',
#   u'(2010)',
#   u'/title/tt1282140/',
#   u'Users rated this 7.1/10 (251,272 votes) - click stars to rate',
#   u'7.1',
#   u"A clean-cut high school student relies on the school's rumor mill to advance her social and financial standing.",
#   u'Will Gluck',
#   u'Emma Stone, Amanda Bynes, Penn Badgley',
#   u'Comedy | Romance',
#   u'PG_13',
#   u'92 mins.'],
#  [u'Iron Man 2',
#   u'(2010)',
#   u'/title/tt1228705/',
#   u'Users rated this 7.0/10 (463,469 votes) - click stars to rate',
#   u'7.0',
#   u"With the world now aware of his identity as Iron Man, Tony Stark must contend with both his declining health and a vengeful mad man with ties to his father's legacy.",
#   u'Jon Favreau',
#   u'Robert Downey Jr., Mickey Rourke, Gwyneth Paltrow',
#   u'Action | Adventure | Sci-Fi',
#   u'PG_13',
#   u'124 mins.'],
#  [u'The Town',
#   u'(2010)',
#   u'/title/tt0840361/',
#   u'Users rated this 7.6/10 (262,861 votes) - click stars to rate',
#   u'7.6',
#   u'As he plans his next job, a longtime thief tries to balance his feelings for a bank manager connected to one of his earlier heists, as well as the FBI agent looking to bring him and his crew down.',
#   u'Ben Affleck',
#   u'Ben Affleck, Rebecca Hall, Jon Hamm',
#   u'Crime | Drama | Thriller',
#   u'R',
#   u'125 mins.'],
#  [u'TRON: Legacy',
#   u'(2010)',
#   u'/title/tt1104001/',
#   u'Users rated this 6.8/10 (249,283 votes) - click stars to rate',
#   u'6.8',
#   u"The son of a virtual world designer goes looking for his father and ends up inside the digital world that his father designed. He meets his father's corrupted creation and a unique ally who was born inside the digital world.",
#   u'Joseph Kosinski',
#   u'Jeff Bridges, Garrett Hedlund, Olivia Wilde',
#   u'Action | Adventure | Fantasy | Sci-Fi',
#   u'PG',
#   u'125 mins.'],
#  [u'Love & Other Drugs',
#   u'(2010)',
#   u'/title/tt0758752/',
#   u'Users rated this 6.7/10 (131,879 votes) - click stars to rate',
#   u'6.7',
#   u"A young woman suffering from Parkinson's befriends a drug rep working for Pfizer in 1990s Pittsburgh.",
#   u'Edward Zwick',
#   u'Jake Gyllenhaal, Anne Hathaway, Judy Greer',
#   u'Comedy | Drama | Romance',
#   u'R',
#   u'112 mins.'],
#  [u'Grown Ups',
#   u'(2010)',
#   u'/title/tt1375670/',
#   u'Users rated this 6.0/10 (167,028 votes) - click stars to rate',
#   u'6.0',
#   u'After their high school basketball coach passes away, five good friends and former teammates reunite for a Fourth of July holiday weekend.',
#   u'Dennis Dugan',
#   u'Adam Sandler, Salma Hayek, Kevin James',
#   u'Comedy',
#   u'PG_13',
#   u'102 mins.'],
#  [u'True Grit',
#   u'(2010)',
#   u'/title/tt1403865/',
#   u'Users rated this 7.7/10 (222,267 votes) - click stars to rate',
#   u'7.7',
#   u"A tough U.S. Marshal helps a stubborn teenager track down her father's murderer.",
#   u'Ethan Coen, Joel Coen',
#   u'Jeff Bridges, Matt Damon, Hailee Steinfeld',
#   u'Adventure | Drama | Western',
#   u'PG_13',
#   u'110 mins.'],
#  [u'The Fighter',
#   u'(2010)',
#   u'/title/tt0964517/',
#   u'Users rated this 7.9/10 (254,540 votes) - click stars to rate',
#   u'7.9',
#   u'A look at the early years of boxer "Irish" Micky Ward and his brother who helped train him before going pro in the mid 1980s.',
#   u'David O. Russell',
#   u'Mark Wahlberg, Christian Bale, Amy Adams',
#   u'Biography | Drama | Sport',
#   u'R',
#   u'116 mins.'],
#  [u'The Last Airbender',
#   u'(2010)',
#   u'/title/tt0938283/',
#   u'Users rated this 4.3/10 (112,133 votes) - click stars to rate',
#   u'4.3',
#   u'Follows the adventures of Aang, a young successor to a long line of Avatars, who must master all four elements and stop the Fire Nation from enslaving the Water Tribes and the Earth Kingdom.',
#   u'M. Night Shyamalan',
#   u'Noah Ringer, Nicola Peltz, Jackson Rathbone',
#   u'Action | Adventure | Family | Fantasy',
#   u'PG',
#   u'103 mins.'],
#  [u'The American',
#   u'(2010)',
#   u'/title/tt1440728/',
#   u'Users rated this 6.3/10 (75,681 votes) - click stars to rate',
#   u'6.3',
#   u'An assassin hides out in Italy for one last assignment.',
#   u'Anton Corbijn',
#   u'George Clooney, Paolo Bonacelli, Violante Placido',
#   u'Crime | Drama | Thriller',
#   u'R',
#   u'105 mins.'],
#  [u'Never Let Me Go',
#   u'(2010)',
#   u'/title/tt1334260/',
#   u'Users rated this 7.2/10 (101,706 votes) - click stars to rate',
#   u'7.2',
#   u'The lives of three friends, from their early school days into young adulthood.',
#   u'Mark Romanek',
#   u'Keira Knightley, Carey Mulligan, Andrew Garfield',
#   u'Drama | Romance | Sci-Fi',
#   u'R',
#   u'103 mins.'],
#  [u"The King's Speech",
#   u'(2010)',
#   u'/title/tt1504320/',
#   u'Users rated this 8.1/10 (446,353 votes) - click stars to rate',
#   u'8.1',
#   u'The story of King George VI of the United Kingdom of Great Britain and Northern Ireland, his impromptu ascension to the throne and the speech therapist who helped the unsure monarch become worthy of it.',
#   u'Tom Hooper',
#   u'Colin Firth, Geoffrey Rush, Helena Bonham Carter',
#   u'Biography | Drama',
#   u'R',
#   u'118 mins.'],
#  [u'Hot Tub Time Machine',
#   u'(2010)',
#   u'/title/tt1231587/',
#   u'Users rated this 6.5/10 (132,564 votes) - click stars to rate',
#   u'6.5',
#   u'A malfunctioning time machine at a ski resort takes a man back to 1986 with his two friends and nephew, where they must relive a fateful night and not change anything to make sure the nephew is born.',
#   u'Steve Pink',
#   u'John Cusack, Rob Corddry, Craig Robinson',
#   u'Comedy | Sci-Fi',
#   u'R',
#   u'101 mins.'],
#  [u'The Twilight Saga: Eclipse',
#   u'(2010)',
#   u'/title/tt1325004/',
#   u'Users rated this 4.9/10 (173,215 votes) - click stars to rate',
#   u'4.9',
#   u'As a string of mysterious killings grips Seattle, Bella, whose high school graduation is fast approaching, is forced to choose between her love for vampire Edward and her friendship with werewolf Jacob.',
#   u'David Slade',
#   u'Kristen Stewart, Robert Pattinson, Taylor Lautner',
#   u'Adventure | Drama | Fantasy | Romance',
#   u'PG_13',
#   u'124 mins.'],
#  [u'Remember Me',
#   u'(2010)',
#   u'/title/tt1403981/',
#   u'Users rated this 7.2/10 (106,250 votes) - click stars to rate',
#   u'7.2',
#   u"A romantic drama centered on two new lovers: Tyler, whose parents have split in the wake of his brother's suicide, and Ally, who lives each day to the fullest since witnessing her mother's murder.",
#   u'Allen Coulter',
#   u'Robert Pattinson, Emilie de Ravin, Caitlyn Rund',
#   u'Drama | Romance',
#   u'PG_13',
#   u'113 mins.'],
#  [u"Winter's Bone",
#   u'(2010)',
#   u'/title/tt1399683/',
#   u'Users rated this 7.2/10 (104,962 votes) - click stars to rate',
#   u'7.2',
#   u'An unflinching Ozark Mountain girl hacks through dangerous social terrain as she hunts down her drug-dealing father while trying to keep her family intact.',
#   u'Debra Granik',
#   u'Jennifer Lawrence, John Hawkes, Garret Dillahunt',
#   u'Drama',
#   u'R',
#   u'100 mins.'],
#  [u'Legion',
#   u'(2010)',
#   u'/title/tt1038686/',
#   u'Users rated this 5.2/10 (76,046 votes) - click stars to rate',
#   u'5.2',
#   u'A group of strangers fight for the welfare of humanity.',
#   u'Scott Stewart',
#   u'Paul Bettany, Dennis Quaid, Charles S. Dutton',
#   u'Action | Fantasy | Horror',
#   u'R',
#   u'100 mins.'],
#  [u'Devil',
#   u'(2010)',
#   u'/title/tt1314655/',
#   u'Users rated this 6.3/10 (97,486 votes) - click stars to rate',
#   u'6.3',
#   u'A group of people are trapped in an elevator and the Devil is mysteriously amongst them.',
#   u'John Erick Dowdle',
#   u'Chris Messina, Caroline Dhavernas, Bokeem Woodbine',
#   u'Drama | Horror | Mystery | Thriller',
#   u'PG_13',
#   u'80 mins.'],
#  [u'Tucker and Dale vs. Evil',
#   u'(2010)',
#   u'/title/tt1465522/',
#   u'Users rated this 7.6/10 (115,159 votes) - click stars to rate',
#   u'7.6',
#   u'Tucker & Dale are on vacation at their dilapidated mountain cabin when they are attacked by a group of preppy college kids.',
#   u'Eli Craig',
#   u'Tyler Labine, Alan Tudyk, Katrina Bowden',
#   u'Comedy | Horror',
#   u'R',
#   u'89 mins.'],
#  [u'The Losers',
#   u'(2010)',
#   u'/title/tt0480255/',
#   u'Users rated this 6.4/10 (70,951 votes) - click stars to rate',
#   u'6.4',
#   u'A CIA special forces team are betrayed and left for dead by their superiors, galvanizing them to mount an offensive on the CIA.',
#   u'Sylvain White',
#   u'Idris Elba, Zoe Saldana, Jeffrey Dean Morgan',
#   u'Action | Crime | Drama | Mystery | Thriller',
#   u'PG_13',
#   u'97 mins.'],
#  [u'Alice in Wonderland',
#   u'(2010)',
#   u'/title/tt1014759/',
#   u'Users rated this 6.5/10 (278,387 votes) - click stars to rate',
#   u'6.5',
#   u"Nineteen-year-old Alice returns to the magical world from her childhood adventure, where she reunites with her old friends and learns of her true destiny: to end the Red Queen's reign of terror.",
#   u'Tim Burton',
#   u'Mia Wasikowska, Johnny Depp, Helena Bonham Carter',
#   u'Adventure | Family | Fantasy',
#   u'PG',
#   u'108 mins.'],
#  [u'Kick-Ass',
#   u'(2010)',
#   u'/title/tt1250777/',
#   u'Users rated this 7.7/10 (404,670 votes) - click stars to rate',
#   u'7.7',
#   u'Dave Lizewski is an unnoticed high school student and comic book fan who one day decides to become a super-hero, even though he has no powers, training or meaningful reason to do so.',
#   u'Matthew Vaughn',
#   u'Aaron Taylor-Johnson, Nicolas Cage, Chlo\xc3\xab Grace Moretz',
#   u'Action | Comedy',
#   u'R',
#   u'117 mins.'],
#  [u'Black Swan',
#   u'(2010)',
#   u'/title/tt0947798/',
#   u'Users rated this 8.0/10 (509,396 votes) - click stars to rate',
#   u'8.0',
#   u'A ballet dancer wins the lead in "Swan Lake" and is perfect for the role of the delicate White Swan - Princess Odette - but slowly loses her mind as she becomes more and more like Odile, the Black Swan.',
#   u'Darren Aronofsky',
#   u'Natalie Portman, Mila Kunis, Vincent Cassel',
#   u'Drama | Thriller',
#   u'R',
#   u'108 mins.'],
#  [u'Prince of Persia: The Sands of Time',
#   u'(2010)',
#   u'/title/tt0473075/',
#   u'Users rated this 6.6/10 (205,930 votes) - click stars to rate',
#   u'6.6',
#   u'A young fugitive prince and princess must stop a villain who unknowingly threatens to destroy the world with a special dagger that enables the magic sand inside to reverse time.',
#   u'Mike Newell',
#   u'Jake Gyllenhaal, Gemma Arterton, Ben Kingsley',
#   u'Action | Adventure | Fantasy | Romance',
#   u'PG_13',
#   u'116 mins.'],
#  [u'The Social Network',
#   u'(2010)',
#   u'/title/tt1285016/',
#   u'Users rated this 7.8/10 (433,785 votes) - click stars to rate',
#   u'7.8',
#   u'Harvard student Mark Zuckerberg creates the social networking site that would become known as Facebook, but is later sued by two brothers who claimed he stole their idea, and the cofounder who was later squeezed out of the business.',
#   u'David Fincher',
#   u'Jesse Eisenberg, Andrew Garfield, Justin Timberlake',
#   u'Biography | Drama',
#   u'PG_13',
#   u'120 mins.'],
#  [u'RED',
#   u'(2010)',
#   u'/title/tt1245526/',
#   u'Users rated this 7.1/10 (222,894 votes) - click stars to rate',
#   u'7.1',
#   u'When his peaceful life is threatened by a high-tech assassin, former black-ops agent Frank Moses reassembles his old team in a last ditch effort to survive and uncover his assailants.',
#   u'Robert Schwentke',
#   u'Bruce Willis, Helen Mirren, Morgan Freeman',
#   u'Action | Comedy | Crime | Thriller',
#   u'PG_13',
#   u'111 mins.'],
#  [u'Percy Jackson & the Olympians: The Lightning Thief',
#   u'(2010)',
#   u'/title/tt0814255/',
#   u'Users rated this 5.9/10 (130,849 votes) - click stars to rate',
#   u'5.9',
#   u"A teenager discovers he's the descendant of a Greek god and sets out on an adventure to settle an on-going battle between the gods.",
#   u'Chris Columbus',
#   u'Logan Lerman, Kevin McKidd, Steve Coogan',
#   u'Adventure | Family | Fantasy',
#   u'PG',
#   u'118 mins.'],
#  [u'Harry Potter and the Deathly Hallows: Part 1',
#   u'(2010)',
#   u'/title/tt0926084/',
#   u'Users rated this 7.7/10 (294,283 votes) - click stars to rate',
#   u'7.7',
#   u'As Harry races against time and evil to destroy the Horcruxes, he uncovers the existence of three most powerful objects in the wizarding world: the Deathly Hallows.',
#   u'David Yates',
#   u'Daniel Radcliffe, Emma Watson, Rupert Grint',
#   u'Adventure | Family | Fantasy | Mystery',
#   u'PG_13',
#   u'146 mins.'],
#  [u'Clash of the Titans',
#   u'(2010)',
#   u'/title/tt0800320/',
#   u'Users rated this 5.8/10 (216,056 votes) - click stars to rate',
#   u'5.8',
#   u'Perseus, mortal son of Zeus, battles the minions of the underworld to stop them from conquering heaven and earth.',
#   u'Louis Leterrier',
#   u'Sam Worthington, Liam Neeson, Ralph Fiennes',
#   u'Action | Adventure | Fantasy',
#   u'',
#   u'106 mins.'],
#  [u'The Expendables',
#   u'(2010)',
#   u'/title/tt1320253/',
#   u'Users rated this 6.5/10 (249,897 votes) - click stars to rate',
#   u'6.5',
#   u'A CIA operative hires a team of mercenaries to eliminate a Latin dictator and a renegade CIA agent.',
#   u'Sylvester Stallone',
#   u'Sylvester Stallone, Jason Statham, Jet Li',
#   u'Action | Adventure | Thriller',
#   u'R',
#   u'103 mins.'],
#  [u'Tangled',
#   u'(2010)',
#   u'/title/tt0398286/',
#   u'Users rated this 7.8/10 (260,411 votes) - click stars to rate',
#   u'7.8',
#   u'The magically long-haired Rapunzel has spent her entire life in a tower, but now that a runaway thief has stumbled upon her, she is about to discover the world for the first time, and who she really is.',
#   u'Nathan Greno, Byron Howard',
#   u'Mandy Moore, Zachary Levi, Donna Murphy',
#   u'Animation | Comedy | Family | Fantasy | Musical | Romance',
#   u'PG',
#   u'100 mins.'],
#  [u'A Serbian Film',
#   u'(2010)',
#   u'/title/tt1273235/',
#   u'Users rated this 5.3/10 (34,418 votes) - click stars to rate',
#   u'5.3',
#   u'An aging porn star agrees to participate in an "art film" in order to make a clean break from the business, only to discover that he has been drafted into making a pedophilia and necrophilia themed snuff film.',
#   u'Srdjan Spasojevic',
#   u'Srdjan Todorovic, Sergej Trifunovic, Jelena Gavrilovic',
#   u'Drama | Horror | Mystery | Thriller',
#   u'NC_17',
#   u'104 mins.'],
#  [u'Incendies',
#   u'(2010)',
#   u'/title/tt1255953/',
#   u'Users rated this 8.2/10 (67,520 votes) - click stars to rate',
#   u'8.2',
#   u"Twins journey to the Middle East to discover their family history, and fulfill their mother's last wishes.",
#   u'Denis Villeneuve',
#   u'Lubna Azabal, M\xc3\xa9lissa D\xc3\xa9sormeaux-Poulin, Maxim Gaudette',
#   u'Drama | Mystery | War',
#   u'R',
#   u'139 mins.'],
#  [u'How to Train Your Dragon',
#   u'(2010)',
#   u'/title/tt0892769/',
#   u'Users rated this 8.2/10 (427,436 votes) - click stars to rate',
#   u'8.2',
#   u'A hapless young Viking who aspires to hunt dragons becomes the unlikely friend of a young dragon himself, and learns there may be more to the creatures than he assumed.',
#   u'Dean DeBlois, Chris Sanders',
#   u'Jay Baruchel, Gerard Butler, Christopher Mintz-Plasse',
#   u'Animation | Adventure | Family | Fantasy',
#   u'PG',
#   u'98 mins.'],
#  [u'Toy Story 3',
#   u'(2010)',
#   u'/title/tt0435761/',
#   u'Users rated this 8.4/10 (482,368 votes) - click stars to rate',
#   u'8.4',
#   u"The toys are mistakenly delivered to a day-care center instead of the attic right before Andy leaves for college, and it's up to Woody to convince the other toys that they weren't abandoned and to return home.",
#   u'Lee Unkrich',
#   u'Tom Hanks, Tim Allen, Joan Cusack',
#   u'Animation | Adventure | Comedy | Family | Fantasy',
#   u'G',
#   u'103 mins.'],
#  [u'Burlesque',
#   u'(2010)',
#   u'/title/tt1126591/',
#   u'Users rated this 6.4/10 (57,611 votes) - click stars to rate',
#   u'6.4',
#   u'A small-town girl ventures to Los Angeles and finds her place in a neo-burlesque club run by a former dancer.',
#   u'Steve Antin',
#   u'Cher, Christina Aguilera, Alan Cumming',
#   u'Drama | Music | Romance',
#   u'PG_13',
#   u'119 mins.'],
#  [u'127 Hours',
#   u'(2010)',
#   u'/title/tt1542344/',
#   u'Users rated this 7.6/10 (257,702 votes) - click stars to rate',
#   u'7.6',
#   u'An adventurous mountain climber becomes trapped under a boulder while canyoneering alone near Moab, Utah and resorts to desperate measures in order to survive.',
#   u'Danny Boyle',
#   u'James Franco, Amber Tamblyn, Kate Mara',
#   u'Adventure | Biography | Drama | Thriller',
#   u'R',
#   u'94 mins.'],
#  [u'Megamind',
#   u'(2010)',
#   u'/title/tt1001526/',
#   u'Users rated this 7.3/10 (156,605 votes) - click stars to rate',
#   u'7.3',
#   u'The supervillain Megamind finally defeats his nemesis, the superhero Metro Man. But without a hero, he loses all purpose and must find new meaning to his life.',
#   u'Tom McGrath',
#   u'Will Ferrell, Jonah Hill, Brad Pitt',
#   u'Animation | Action | Comedy | Family | Sci-Fi',
#   u'PG',
#   u'95 mins.'],
#  [u'The A-Team',
#   u'(2010)',
#   u'/title/tt0429493/',
#   u'Users rated this 6.8/10 (199,346 votes) - click stars to rate',
#   u'6.8',
#   u'A group of Iraq War veterans looks to clear their name with the U.S. military, who suspect the four men of committing a crime for which they were framed.',
#   u'Joe Carnahan',
#   u'Liam Neeson, Bradley Cooper, Sharlto Copley',
#   u'Action | Adventure | Comedy | Crime | Thriller',
#   u'PG_13',
#   u'117 mins.'],
#  [u'I Spit on Your Grave',
#   u'(2010)',
#   u'/title/tt1242432/',
#   u'Users rated this 6.3/10 (50,193 votes) - click stars to rate',
#   u'6.3',
#   u'A writer who is brutalized during her cabin retreat seeks revenge on her attackers, who left her for dead.',
#   u'Steven R. Monroe',
#   u'Sarah Butler, Jeff Branson, Andrew Howard',
#   u'Crime | Horror | Thriller',
#   u'UNRATED',
#   u'108 mins.'],
#  [u'Leap Year',
#   u'(2010)',
#   u'/title/tt1216492/',
#   u'Users rated this 6.4/10 (65,139 votes) - click stars to rate',
#   u'6.4',
#   u'Anna Brady plans to travel to Dublin, Ireland to propose marriage to her boyfriend Jeremy on Leap Day, because, according to Irish tradition, a man who receives a marriage proposal on a leap day must accept it.',
#   u'Anand Tucker',
#   u'Amy Adams, Matthew Goode, Adam Scott',
#   u'Comedy | Romance',
#   u'PG',
#   u'100 mins.'],
#  [u'The Chronicles of Narnia: The Voyage of the Dawn Treader',
#   u'(2010)',
#   u'/title/tt0980970/',
#   u'Users rated this 6.3/10 (96,523 votes) - click stars to rate',
#   u'6.3',
#   u'Lucy and Edmund Pevensie return to Narnia with their cousin Eustace where they meet up with Prince Caspian for a trip across the sea aboard the royal ship The Dawn Treader. Along the way they encounter dragons, dwarves, merfolk, and a band of lost warriors before reaching the edge of the world.',
#   u'Michael Apted',
#   u'Ben Barnes, Skandar Keynes, Georgie Henley',
#   u'Adventure | Family | Fantasy',
#   u'PG',
#   u'113 mins.'],
#  [u'Blue Valentine',
#   u'(2010)',
#   u'/title/tt1120985/',
#   u'Users rated this 7.4/10 (131,233 votes) - click stars to rate',
#   u'7.4',
#   u'The relationship of a contemporary married couple, charting their evolution over a span of years by cross-cutting between time periods.',
#   u'Derek Cianfrance',
#   u'Ryan Gosling, Michelle Williams, John Doman',
#   u'Drama | Romance',
#   u'R',
#   u'112 mins.'],
#  [u'The Other Guys',
#   u'(2010)',
#   u'/title/tt1386588/',
#   u'Users rated this 6.6/10 (175,039 votes) - click stars to rate',
#   u'6.6',
#   u"Two mismatched New York City detectives seize an opportunity to step up like the city's top cops whom they idolize -- only things don't quite go as planned.",
#   u'Adam McKay',
#   u'Will Ferrell, Mark Wahlberg, Derek Jeter',
#   u'Action | Comedy | Crime',
#   u'PG_13',
#   u'107 mins.'],
#  [u'Unstoppable',
#   u'(2010)',
#   u'/title/tt0477080/',
#   u'Users rated this 6.8/10 (139,414 votes) - click stars to rate',
#   u'6.8',
#   u'With an unmanned, half-mile-long freight train barreling toward a city, a veteran engineer and a young conductor race against the clock to prevent a catastrophe.',
#   u'Tony Scott',
#   u'Denzel Washington, Chris Pine, Rosario Dawson',
#   u'Action | Thriller',
#   u'PG_13',
#   u'98 mins.'],
#  [u'The Karate Kid',
#   u'(2010)',
#   u'/title/tt1155076/',
#   u'Users rated this 6.2/10 (110,151 votes) - click stars to rate',
#   u'6.2',
#   u'Work causes a single mother to move to China with her young son; in his new home, the boy embraces kung fu, taught to him by a master.',
#   u'Harald Zwart',
#   u'Jackie Chan, Jaden Smith, Taraji P. Henson',
#   u'Action | Drama | Family | Sport',
#   u'PG',
#   u'140 mins.'],
#  [u'A Nightmare on Elm Street',
#   u'(2010)',
#   u'/title/tt1179056/',
#   u'Users rated this 5.2/10 (70,392 votes) - click stars to rate',
#   u'5.2',
#   u'The spectre of a dead child rapist haunts the children of the parents who murdered him, stalking and killing them in their dreams.',
#   u'Samuel Bayer',
#   u'Jackie Earle Haley, Rooney Mara, Kyle Gallner',
#   u'Horror | Mystery | Thriller',
#   u'R',
#   u'95 mins.'],
#  [u'Elite Squad: The Enemy Within',
#   u'(2010)',
#   u'/title/tt1555149/',
#   u'Users rated this 8.1/10 (61,082 votes) - click stars to rate',
#   u'8.1',
#   u'After a prison riot, former-Captain Nascimento, now a high ranking security officer in Rio de Janeiro, is swept into a bloody political dispute that involves government officials and paramilitary groups.',
#   u'Jos\xc3\xa9 Padilha',
#   u'Wagner Moura, Irandhir Santos, Andr\xc3\xa9 Ramiro',
#   u'Action | Crime | Drama | Thriller',
#   u'UNRATED',
#   u'115 mins.'],
#  [u'The Last Song',
#   u'(2010)',
#   u'/title/tt1294226/',
#   u'Users rated this 5.8/10 (56,328 votes) - click stars to rate',
#   u'5.8',
#   u'A rebellious girl is sent to a Southern beach town for the summer to stay with her father. Through their mutual love of music, the estranged duo learn to reconnect.',
#   u'Julie Anne Robinson',
#   u'Miley Cyrus, Liam Hemsworth, Greg Kinnear',
#   u'Drama | Romance',
#   u'PG',
#   u'107 mins.'],
#  [u'Predators',
#   u'(2010)',
#   u'/title/tt1424381/',
#   u'Users rated this 6.4/10 (161,805 votes) - click stars to rate',
#   u'6.4',
#   u'A group of elite warriors are hunted by members of a merciless alien race known as Predators.',
#   u'Nimr\xc3\xb3d Antal',
#   u'Adrien Brody, Laurence Fishburne, Topher Grace',
#   u'Action | Adventure | Sci-Fi | Thriller',
#   u'R',
#   u'107 mins.'],
#  [u'Tomorrow, When the War Began',
#   u'(2010)',
#   u'/title/tt1456941/',
#   u'Users rated this 6.2/10 (25,529 votes) - click stars to rate',
#   u'6.2',
#   u'When their country is invaded and their families are taken, eight unlikely high school teenagers band together to fight.',
#   u'Stuart Beattie',
#   u'Caitlin Stasey, Rachel Hurd-Wood, Lincoln Lewis',
#   u'Action | Adventure | Drama | War',
#   u'R',
#   u'103 mins.'],
#  [u'Knight and Day',
#   u'(2010)',
#   u'/title/tt1013743/',
#   u'Users rated this 6.3/10 (138,896 votes) - click stars to rate',
#   u'6.3',
#   u'A young woman gets mixed up with a disgraced spy who is trying to clear his name.',
#   u'James Mangold',
#   u'Tom Cruise, Cameron Diaz, Peter Sarsgaard',
#   u'Action | Comedy | Romance',
#   u'PG_13',
#   u'109 mins.'],
#  [u'Dinner for Schmucks',
#   u'(2010)',
#   u'/title/tt0427152/',
#   u'Users rated this 5.9/10 (75,533 votes) - click stars to rate',
#   u'5.9',
#   u"When he finds out that his work superiors host a dinner celebrating the idiocy of their guests, a rising executive questions it when he's invited, just as he befriends a man who would be the perfect guest.",
#   u'Jay Roach',
#   u'Steve Carell, Paul Rudd, Stephanie Szostak',
#   u'Comedy',
#   u'PG_13',
#   u'114 mins.'],
#  [u'Takers',
#   u'(2010)',
#   u'/title/tt1135084/',
#   u'Users rated this 6.2/10 (44,253 votes) - click stars to rate',
#   u'6.2',
#   u'A group of bank robbers find their multi-million dollar plan interrupted by a hard-boiled detective.',
#   u'John Luessenhop',
#   u'Chris Brown, Hayden Christensen, Matt Dillon',
#   u'Action | Crime | Thriller',
#   u'PG_13',
#   u'107 mins.'],
#  [u'Salt',
#   u'(2010)',
#   u'/title/tt0944835/',
#   u'Users rated this 6.4/10 (230,774 votes) - click stars to rate',
#   u'6.4',
#   u'A CIA agent goes on the run after a defector accuses her of being a Russian spy.',
#   u'Phillip Noyce',
#   u'Angelina Jolie, Liev Schreiber, Chiwetel Ejiofor',
#   u'Action | Crime | Mystery | Thriller',
#   u'PG_13',
#   u'100 mins.'],
#  [u'Eat Pray Love',
#   u'(2010)',
#   u'/title/tt0879870/',
#   u'Users rated this 5.6/10 (57,501 votes) - click stars to rate',
#   u'5.6',
#   u'A married woman realizes how unhappy her marriage really is, and that her life needs to go in a different direction. After a painful divorce, she takes off on a round-the-world journey to "find herself".',
#   u'Ryan Murphy',
#   u'Julia Roberts, Javier Bardem, Richard Jenkins',
#   u'Drama | Romance',
#   u'R',
#   u'133 mins.'],
#  [u'Flipped',
#   u'(2010)',
#   u'/title/tt0817177/',
#   u'Users rated this 7.7/10 (54,378 votes) - click stars to rate',
#   u'7.7',
#   u'Two eighth-graders start to have feelings for each other despite being total opposites. Based on the novel "Flipped" by Wendelin Van Draanen.',
#   u'Rob Reiner',
#   u'Madeline Carroll, Callan McAuliffe, Rebecca De Mornay',
#   u'Comedy | Drama | Romance',
#   u'PG',
#   u'90 mins.'],
#  [u"The Sorcerer's Apprentice",
#   u'(2010)',
#   u'/title/tt0963966/',
#   u'Users rated this 6.1/10 (116,647 votes) - click stars to rate',
#   u'6.1',
#   u"Master sorcerer Balthazar Blake must find and train Merlin's descendant to defeat dark sorceress Morgana le Fey.",
#   u'Jon Turteltaub',
#   u'Nicolas Cage, Jay Baruchel, Alfred Molina',
#   u'Action | Adventure | Comedy | Drama | Fantasy',
#   u'PG',
#   u'109 mins.'],
#  [u'The Next Three Days',
#   u'(2010)',
#   u'/title/tt1458175/',
#   u'Users rated this 7.4/10 (137,304 votes) - click stars to rate',
#   u'7.4',
#   u"A married couple's life is turned upside down when the wife is accused of a murder.",
#   u'Paul Haggis',
#   u'Russell Crowe, Elizabeth Banks, Liam Neeson',
#   u'Crime | Drama | Romance | Thriller',
#   u'PG_13',
#   u'133 mins.'],
#  [u"She's Out of My League",
#   u'(2010)',
#   u'/title/tt0815236/',
#   u'Users rated this 6.4/10 (96,468 votes) - click stars to rate',
#   u'6.4',
#   u'An average Joe meets the perfect woman, but his lack of confidence and the influence of his friends and family begin to pick away at the relationship.',
#   u'Jim Field Smith',
#   u'Jay Baruchel, Alice Eve, T.J. Miller',
#   u'Comedy | Romance',
#   u'R',
#   u'104 mins.'],
#  [u'The Way Back',
#   u'(2010)',
#   u'/title/tt1023114/',
#   u'Users rated this 7.3/10 (81,859 votes) - click stars to rate',
#   u'7.3',
#   u'Siberian gulag escapees travel 4,000 miles by foot to freedom in India.',
#   u'Peter Weir',
#   u'Jim Sturgess, Ed Harris, Colin Farrell',
#   u'Adventure | Drama | History',
#   u'PG_13',
#   u'133 mins.'],
#  [u'Piranha 3D',
#   u'(2010)',
#   u'/title/tt0464154/',
#   u'Users rated this 5.5/10 (68,955 votes) - click stars to rate',
#   u'5.5',
#   u"After a sudden underwater tremor sets free scores of the prehistoric man-eating fish, an unlikely group of strangers must band together to stop themselves from becoming fish food for the area's new razor-toothed residents.",
#   u'Alexandre Aja',
#   u"Elisabeth Shue, Jerry O'Connell, Richard Dreyfuss",
#   u'Comedy | Horror',
#   u'R',
#   u'88 mins.'],
#  [u'Letters to Juliet',
#   u'(2010)',
#   u'/title/tt0892318/',
#   u'Users rated this 6.5/10 (67,065 votes) - click stars to rate',
#   u'6.5',
#   u'Sophie dreams of becoming a writer and travels to Verona, Italy where she meets the "Secretaries of Juliet".',
#   u'Gary Winick',
#   u'Amanda Seyfried, Gael Garc\xc3\xada Bernal, Vanessa Redgrave',
#   u'Comedy | Drama | Romance',
#   u'PG',
#   u'105 mins.'],
#  [u'When in Rome',
#   u'(2010)',
#   u'/title/tt1185416/',
#   u'Users rated this 5.5/10 (47,325 votes) - click stars to rate',
#   u'5.5',
#   u'Beth is a young, ambitious New Yorker who is completely unlucky in love. However, on a whirlwind trip to Rome, she impulsively steals some coins from a reputed fountain of love, and is then aggressively pursued by a band of suitors.',
#   u'Mark Steven Johnson',
#   u'Kristen Bell, Josh Duhamel, Anjelica Huston',
#   u'Comedy | Romance',
#   u'PG_13',
#   u'91 mins.'],
#  [u'Faster',
#   u'(2010)',
#   u'/title/tt1433108/',
#   u'Users rated this 6.5/10 (76,449 votes) - click stars to rate',
#   u'6.5',
#   u"An ex-con sets out to avenge his brother's death after they were double-crossed during a heist years ago. During his campaign, however, he's tracked by a veteran cop and an egocentric hit man.",
#   u'George Tillman Jr.',
#   u'Dwayne Johnson, Billy Bob Thornton, Maggie Grace',
#   u'Action | Crime | Drama | Thriller',
#   u'R',
#   u'98 mins.'],
#  [u'Due Date',
#   u'(2010)',
#   u'/title/tt1231583/',
#   u'Users rated this 6.6/10 (259,309 votes) - click stars to rate',
#   u'6.6',
#   u"High-strung father-to-be Peter Highman is forced to hitch a ride with aspiring actor Ethan Tremblay on a road trip in order to make it to his child's birth on time.",
#   u'Todd Phillips',
#   u'Robert Downey Jr., Zach Galifianakis, Michelle Monaghan',
#   u'Comedy',
#   u'R',
#   u'95 mins.'],
#  [u'Trust',
#   u'(2010)',
#   u'/title/tt1529572/',
#   u'Users rated this 7.0/10 (32,232 votes) - click stars to rate',
#   u'7.0',
#   u'A teenage girl is targeted by an online sexual predator.',
#   u'David Schwimmer',
#   u'Clive Owen, Catherine Keener, Liana Liberato',
#   u'Crime | Drama | Thriller',
#   u'R',
#   u'106 mins.'],
#  [u'Wall Street: Money Never Sleeps',
#   u'(2010)',
#   u'/title/tt1027718/',
#   u'Users rated this 6.3/10 (79,447 votes) - click stars to rate',
#   u'6.3',
#   u'Now out of prison but still disgraced by his peers, Gordon Gekko works his future son-in-law, an idealistic stock broker, when he sees an opportunity to take down a Wall Street enemy and rebuild his empire.',
#   u'Oliver Stone',
#   u'Shia LaBeouf, Michael Douglas, Carey Mulligan',
#   u'Drama',
#   u'PG_13',
#   u'133 mins.'],
#  [u'The Runaways',
#   u'(2010)',
#   u'/title/tt1017451/',
#   u'Users rated this 6.6/10 (37,217 votes) - click stars to rate',
#   u'6.6',
#   u'A coming-of-age biographical film about the 1970s teenage all-girl rock band The Runaways. This film also explores the relationship between band members Joan Jett and Cherie Currie.',
#   u'Floria Sigismondi',
#   u'Kristen Stewart, Dakota Fanning, Michael Shannon',
#   u'Biography | Drama | History | Music',
#   u'R',
#   u'106 mins.'],
#  [u'Date Night',
#   u'(2010)',
#   u'/title/tt1279935/',
#   u'Users rated this 6.3/10 (120,111 votes) - click stars to rate',
#   u'6.3',
#   u"In New York City, a case of mistaken identity turns a bored married couple's attempt at a glamorous and romantic evening into something more thrilling and dangerous.",
#   u'Shawn Levy',
#   u'Steve Carell, Tina Fey, Mark Wahlberg',
#   u'Comedy | Crime | Romance | Thriller',
#   u'PG_13',
#   u'88 mins.'],
#  [u'Sex and the City 2',
#   u'(2010)',
#   u'/title/tt1261945/',
#   u'Users rated this 4.2/10 (55,437 votes) - click stars to rate',
#   u'4.2',
#   u"While wrestling with the pressures of life, love, and work in Manhattan, Carrie, Miranda, and Charlotte join Samantha for a trip to Abu Dhabi (United Arab Emirates), where Samantha's ex is filming a new movie.",
#   u'Michael Patrick King',
#   u'Sarah Jessica Parker, Kim Cattrall, Kristin Davis',
#   u'Comedy | Drama | Romance',
#   u'R',
#   u'146 mins.'],
#  [u'Robin Hood',
#   u'(2010)',
#   u'/title/tt0955308/',
#   u'Users rated this 6.7/10 (198,461 votes) - click stars to rate',
#   u'6.7',
#   u'In 13th century England, Robin and his band of marauders confront corruption in a local village and lead an uprising against the crown that will forever alter the balance of world power.',
#   u'Ridley Scott',
#   u'Russell Crowe, Cate Blanchett, Matthew Macfadyen',
#   u'Action | Adventure | Drama | History',
#   u'PG_13',
#   u'140 mins.'],
#  [u'The Book of Eli',
#   u'(2010)',
#   u'/title/tt1037705/',
#   u'Users rated this 6.9/10 (209,752 votes) - click stars to rate',
#   u'6.9',
#   u'A post-apocalyptic tale, in which a lone man fights his way across America in order to protect a sacred book that holds the secrets to saving humankind.',
#   u'Albert Hughes, Allen Hughes',
#   u'Denzel Washington, Mila Kunis, Ray Stevenson',
#   u'Action | Adventure | Drama | Thriller',
#   u'R',
#   u'118 mins.'],
#  [u'Dear John',
#   u'(2010)',
#   u'/title/tt0989757/',
#   u'Users rated this 6.3/10 (92,021 votes) - click stars to rate',
#   u'6.3',
#   u"A romantic drama about a soldier who falls for a conservative college student while he's home on leave.",
#   u'Lasse Hallstr\xc3\xb6m',
#   u'Channing Tatum, Amanda Seyfried, Richard Jenkins',
#   u'Drama | Romance | War',
#   u'PG_13',
#   u'108 mins.'],
#  [u'The Tourist',
#   u'(2010)',
#   u'/title/tt1243957/',
#   u'Users rated this 6.0/10 (162,199 votes) - click stars to rate',
#   u'6.0',
#   u'Revolves around Frank, an American tourist visiting Italy to mend a broken heart. Elise is an extraordinary woman who deliberately crosses his path.',
#   u'Florian Henckel von Donnersmarck',
#   u'Johnny Depp, Angelina Jolie, Paul Bettany',
#   u'Action | Romance | Thriller',
#   u'PG_13',
#   u'103 mins.'],
#  [u'Let Me In',
#   u'(2010)',
#   u'/title/tt1228987/',
#   u'Users rated this 7.2/10 (85,600 votes) - click stars to rate',
#   u'7.2',
#   u'A bullied young boy befriends a young female vampire who lives in secrecy with her guardian.',
#   u'Matt Reeves',
#   u'Kodi Smit-McPhee, Chlo\xc3\xab Grace Moretz, Richard Jenkins',
#   u'Drama | Horror | Mystery',
#   u'R',
#   u'116 mins.'],
#  [u'Buried',
#   u'(2010)',
#   u'/title/tt1462758/',
#   u'Users rated this 7.0/10 (109,846 votes) - click stars to rate',
#   u'7.0',
#   u"Paul is a U.S. truck driver working in Iraq. After an attack by a group of Iraqis he wakes to find he is buried alive inside a coffin. With only a lighter and a cell phone it's a race against time to escape this claustrophobic death trap.",
#   u'Rodrigo Cort\xc3\xa9s',
#   u'Ryan Reynolds, Jos\xc3\xa9 Luis Garc\xc3\xada P\xc3\xa9rez, Robert Paterson',
#   u'Drama | Mystery | Thriller',
#   u'R',
#   u'95 mins.'],
#  [u'Machete',
#   u'(2010)',
#   u'/title/tt0985694/',
#   u'Users rated this 6.7/10 (157,305 votes) - click stars to rate',
#   u'6.7',
#   u'After being set-up and betrayed by the man who hired him to assassinate a Texas Senator, an ex-Federale launches a brutal rampage of revenge against his former boss.',
#   u'Ethan Maniquis, Robert Rodriguez',
#   u'Danny Trejo, Michelle Rodriguez, Robert De Niro',
#   u'Action | Crime | Thriller',
#   u'R',
#   u'105 mins.'],
#  [u"Valentine's Day",
#   u'(2010)',
#   u'/title/tt0817230/',
#   u'Users rated this 5.8/10 (89,039 votes) - click stars to rate',
#   u'5.8',
#   u"Intertwining couples and singles in Los Angeles break-up and make-up based on the pressures and expectations of Valentine's Day.",
#   u'Garry Marshall',
#   u'Julia Roberts, Jamie Foxx, Anne Hathaway',
#   u'Comedy | Romance',
#   u'PG_13',
#   u'125 mins.'],
#  [u'All Good Things',
#   u'(2010)',
#   u'/title/tt1175709/',
#   u'Users rated this 6.3/10 (37,534 votes) - click stars to rate',
#   u'6.3',
#   u'Mr. David Marks was suspected but never tried for killing his wife Katie who disappeared in 1982, but the truth is eventually revealed.',
#   u'Andrew Jarecki',
#   u'Ryan Gosling, Kirsten Dunst, Frank Langella',
#   u'Crime | Drama | Mystery | Romance | Thriller',
#   u'R',
#   u'101 mins.'],
#  [u'Saw 3D: The Final Chapter',
#   u'(2010)',
#   u'/title/tt1477076/',
#   u'Users rated this 5.6/10 (62,563 votes) - click stars to rate',
#   u'5.6',
#   u"As a deadly battle rages over Jigsaw's brutal legacy, a group of Jigsaw survivors gathers to seek the support of self-help guru and fellow survivor Bobby Dagen, a man whose own dark secrets unleash a new wave of terror.",
#   u'Kevin Greutert',
#   u'Tobin Bell, Costas Mandylor, Betsy Russell',
#   u'Horror | Mystery',
#   u'R',
#   u'90 mins.'],
#  [u"It's Kind of a Funny Story",
#   u'(2010)',
#   u'/title/tt0804497/',
#   u'Users rated this 7.2/10 (97,404 votes) - click stars to rate',
#   u'7.2',
#   u'A clinically depressed teenager gets a new start after he checks himself into an adult psychiatric ward.',
#   u'Anna Boden, Ryan Fleck',
#   u'Keir Gilchrist, Zach Galifianakis, Emma Roberts',
#   u'Comedy | Drama | Romance',
#   u'PG_13',
#   u'101 mins.'],
#  [u'The Wolfman',
#   u'(2010)',
#   u'/title/tt0780653/',
#   u'Users rated this 5.8/10 (86,102 votes) - click stars to rate',
#   u'5.8',
#   u'Upon his return to his ancestral homeland, an American man is bitten, and subsequently cursed by, a werewolf.',
#   u'Joe Johnston',
#   u'Benicio Del Toro, Anthony Hopkins, Emily Blunt',
#   u'Drama | Horror | Thriller',
#   u'R',
#   u'103 mins.'],
#  [u'The Crazies',
#   u'(2010)',
#   u'/title/tt0455407/',
#   u'Users rated this 6.5/10 (87,879 votes) - click stars to rate',
#   u'6.5',
#   u'About the inhabitants of a small Iowa town suddenly plagued by insanity and then death after a mysterious toxin contaminates their water supply.',
#   u'Breck Eisner',
#   u'Radha Mitchell, Timothy Olyphant, Danielle Panabaker',
#   u'Horror | Mystery | Thriller',
#   u'R',
#   u'101 mins.'],
#  [u'Life as We Know It',
#   u'(2010)',
#   u'/title/tt1055292/',
#   u'Users rated this 6.5/10 (86,430 votes) - click stars to rate',
#   u'6.5',
#   u'Two single adults become caregivers to an orphaned girl when their mutual best friends die in an accident.',
#   u'Greg Berlanti',
#   u'Katherine Heigl, Josh Duhamel, Josh Lucas',
#   u'Comedy | Drama | Romance',
#   u'PG_13',
#   u'114 mins.'],
#  [u'The Kids Are All Right',
#   u'(2010)',
#   u'/title/tt0842926/',
#   u'Users rated this 7.1/10 (105,158 votes) - click stars to rate',
#   u'7.1',
#   u'Two children conceived by artificial insemination bring their biological father into their non-traditional family life.',
#   u'Lisa Cholodenko',
#   u'Annette Bening, Julianne Moore, Mark Ruffalo',
#   u'Comedy | Drama',
#   u'R',
#   u'106 mins.'],
#  [u'Resident Evil: Afterlife',
#   u'(2010)',
#   u'/title/tt1220634/',
#   u'Users rated this 5.9/10 (123,344 votes) - click stars to rate',
#   u'5.9',
#   u'While still out to destroy the evil Umbrella Corporation, Alice joins a group of survivors living in a prison surrounded by the infected who also want to relocate to the mysterious but supposedly unharmed safe haven known only as Arcadia.',
#   u'Paul W.S. Anderson',
#   u'Milla Jovovich, Ali Larter, Wentworth Miller',
#   u'Action | Adventure | Horror | Sci-Fi',
#   u'R',
#   u'97 mins.'],
#  [u'Beginners',
#   u'(2010)',
#   u'/title/tt1532503/',
#   u'Users rated this 7.2/10 (67,947 votes) - click stars to rate',
#   u'7.2',
#   u'A young man is rocked by two announcements from his elderly father: that he has terminal cancer, and that he has a young male lover.',
#   u'Mike Mills',
#   u'Ewan McGregor, Christopher Plummer, M\xc3\xa9lanie Laurent',
#   u'Comedy | Drama | Romance',
#   u'R',
#   u'105 mins.'],
#  [u'I Saw the Devil',
#   u'(2010)',
#   u'/title/tt1588170/',
#   u'Users rated this 7.8/10 (63,647 votes) - click stars to rate',
#   u'7.8',
#   u'A secret agent exacts revenge on a serial killer through a series of captures and releases.',
#   u'Jee-woon Kim',
#   u'Byung-hun Lee, Min-sik Choi, In-seo Kim',
#   u'Crime | Drama | Horror | Thriller',
#   u'NOT_RATED',
#   u'141 mins.'],
#  [u'Super',
#   u'(2010)',
#   u'/title/tt1512235/',
#   u'Users rated this 6.8/10 (57,245 votes) - click stars to rate',
#   u'6.8',
#   u'After his wife falls under the influence of a drug dealer, an everyday guy transforms himself into Crimson Bolt, a superhero with the best intentions, but lacking in heroic skills.',
#   u'James Gunn',
#   u'Rainn Wilson, Ellen Page, Liv Tyler',
#   u'Comedy | Crime',
#   u'R',
#   u'96 mins.'],
#  [u'Centurion',
#   u'(2010)',
#   u'/title/tt1020558/',
#   u'Users rated this 6.4/10 (60,652 votes) - click stars to rate',
#   u'6.4',
#   u'A splinter group of Roman soldiers fight for their lives behind enemy lines after their legion is decimated in a devastating guerrilla attack.',
#   u'Neil Marshall',
#   u'Michael Fassbender, Dominic West, Olga Kurylenko',
#   u'Action | Adventure | Drama | History | Thriller | War',
#   u'R',
#   u'97 mins.'],
#  [u'From Paris with Love',
#   u'(2010)',
#   u'/title/tt1179034/',
#   u'Users rated this 6.5/10 (92,663 votes) - click stars to rate',
#   u'6.5',
#   u'In Paris, a young employee in the office of the US Ambassador hooks up with an American spy looking to stop a terrorist attack in the city.',
#   u'Pierre Morel',
#   u'John Travolta, Jonathan Rhys Meyers, Kasia Smutniak',
#   u'Action | Thriller',
#   u'R',
#   u'92 mins.'],
#  [u'The Way',
#   u'(2010)',
#   u'/title/tt1441912/',
#   u'Users rated this 7.4/10 (20,092 votes) - click stars to rate',
#   u'7.4',
#   u'A father heads overseas to recover the body of his estranged son who died while traveling the "El camino de Santiago," and decides to take the pilgrimage himself.',
#   u'Emilio Estevez',
#   u'Martin Sheen, Emilio Estevez, Deborah Kara Unger',
#   u'Adventure | Comedy | Drama',
#   u'PG_13',
#   u'123 mins.'],
#  [u'Diary of a Wimpy Kid',
#   u'(2010)',
#   u'/title/tt1196141/',
#   u'Users rated this 6.2/10 (29,559 votes) - click stars to rate',
#   u'6.2',
#   u'The adventures of a teenager who is fresh out and in Middle School, where he has to learn the consequences and responsibility to survive the year.',
#   u'Thor Freudenthal',
#   u'Zachary Gordon, Robert Capron, Rachael Harris',
#   u'Comedy | Family',
#   u'PG',
#   u'94 mins.'],
#  [u'Submarine',
#   u'(2010)',
#   u'/title/tt1440292/',
#   u'Users rated this 7.3/10 (59,221 votes) - click stars to rate',
#   u'7.3',
#   u'15-year-old Oliver Tate has two objectives: To lose his virginity before his next birthday, and to extinguish the flame between his mother and an ex-lover who has resurfaced in her life.',
#   u'Richard Ayoade',
#   u'Craig Roberts, Sally Hawkins, Paddy Considine',
#   u'Comedy | Drama | Romance',
#   u'R',
#   u'97 mins.'],
#  [u'Killers',
#   u'(2010)',
#   u'/title/tt1103153/',
#   u'Users rated this 5.4/10 (68,465 votes) - click stars to rate',
#   u'5.4',
#   u'A vacationing woman meets her ideal man, leading to a swift marriage. Back at home, however, their idyllic life is upset when they discover their neighbors could be assassins who have been contracted to kill the couple.',
#   u'Robert Luketic',
#   u'Katherine Heigl, Ashton Kutcher, Tom Selleck',
#   u'Action | Comedy | Romance | Thriller',
#   u'PG_13',
#   u'100 mins.'],
#  [u'The Switch',
#   u'(2010)',
#   u'/title/tt0889573/',
#   u'Users rated this 6.1/10 (72,650 votes) - click stars to rate',
#   u'6.1',
#   u"Seven years after the fact, a man comes to the realization that he was the sperm donor for his best friend's boy.",
#   u'Josh Gordon, Will Speck',
#   u'Jennifer Aniston, Jason Bateman, Patrick Wilson',
#   u'Comedy | Drama | Romance',
#   u'PG_13',
#   u'101 mins.'],
#  [u'Monsters',
#   u'(2010)',
#   u'/title/tt1470827/',
#   u'Users rated this 6.4/10 (72,037 votes) - click stars to rate',
#   u'6.4',
#   u'Six years after Earth has suffered an alien invasion a cynical journalist agrees to escort a shaken American tourist through an infected zone in Mexico to the safety of the US border.',
#   u'Gareth Edwards',
#   u'Scoot McNairy, Whitney Able, Mario Zuniga Benavides',
#   u'Drama | Sci-Fi | Thriller',
#   u'R',
#   u'94 mins.'],
#  [u'Frozen',
#   u'(2010)',
#   u'/title/tt1323045/',
#   u'Users rated this 6.2/10 (48,698 votes) - click stars to rate',
#   u'6.2',
#   u'Three skiers stranded on a chairlift are forced to make life-or-death choices which prove more perilous than staying put and freezing to death.',
#   u'Adam Green',
#   u'Shawn Ashmore, Emma Bell, Kevin Zegers',
#   u'Drama | Thriller',
#   u'R',
#   u'93 mins.'],
#  [u'The Man from Nowhere',
#   u'(2010)',
#   u'/title/tt1527788/',
#   u'Users rated this 7.9/10 (38,420 votes) - click stars to rate',
#   u'7.9',
#   u'A quiet pawnshop keeper with a violent past takes on a drug- and organ trafficking ring in hope of saving the child who is his only friend.',
#   u'Jeong-beom Lee',
#   u'Bin Won, Sae-ron Kim, Tae-hoon Kim',
#   u'Action | Crime | Thriller',
#   u'R',
#   u'119 mins.'],
#  [u'Room in Rome',
#   u'(2010)',
#   u'/title/tt1263750/',
#   u'Users rated this 6.2/10 (14,803 votes) - click stars to rate',
#   u'6.2',
#   u'A hotel room in the center of Rome serves as the setting for two young and recently acquainted women to have a physical adventure that touches their very souls.',
#   u'Julio Medem',
#   u'Elena Anaya, Natasha Yarovenko, Enrico Lo Verso',
#   u'Drama | Romance',
#   u'UNRATED',
#   u'109 mins.'],
#  [u'Step Up 3D',
#   u'(2010)',
#   u'/title/tt1193631/',
#   u'Users rated this 6.2/10 (44,023 votes) - click stars to rate',
#   u'6.2',
#   u"A tight-knit group of New York City street dancers find themselves pitted against the world's best hip hop dancers in a high-stakes showdown.",
#   u'Jon M. Chu',
#   u'Sharni Vinson, Rick Malambri, Adam G. Sevani',
#   u'Drama | Music | Romance',
#   u'PG_13',
#   u'107 mins.'],
#  [u'The Back-up Plan',
#   u'(2010)',
#   u'/title/tt1212436/',
#   u'Users rated this 5.3/10 (37,898 votes) - click stars to rate',
#   u'5.3',
#   u'A romantic comedy centered on a woman who conceives twins through artificial insemination, only to meet the man of her dreams on the very same day.',
#   u'Alan Poul',
#   u"Jennifer Lopez, Alex O'Loughlin, Michaela Watkins",
#   u'Comedy | Romance',
#   u'PG_13',
#   u'104 mins.'],
#  [u'Jonah Hex',
#   u'(2010)',
#   u'/title/tt1075747/',
#   u'Users rated this 4.6/10 (42,742 votes) - click stars to rate',
#   u'4.6',
#   u'The U.S. military makes a scarred bounty hunter with warrants on his own head an offer he cannot refuse: in exchange for his freedom, he must stop a terrorist who is ready to unleash Hell on Earth.',
#   u'Jimmy Hayward',
#   u'Josh Brolin, Megan Fox, John Malkovich',
#   u'Action | Drama | Fantasy | Thriller | Western',
#   u'PG_13',
#   u'81 mins.'],
#  [u'Cop Out',
#   u'(2010)',
#   u'/title/tt1385867/',
#   u'Users rated this 5.7/10 (72,326 votes) - click stars to rate',
#   u'5.7',
#   u"A comedy about a veteran NYPD cop whose rare baseball card is stolen. Since it's his only hope to pay for his daughter's upcoming wedding, he recruits his partner to track down the thief, a memorabilia-obsessed gangster.",
#   u'Kevin Smith',
#   u'Bruce Willis, Tracy Morgan, Juan Carlos Hern\xc3\xa1ndez',
#   u'Action | Comedy | Crime',
#   u'R',
#   u'107 mins.'],
#  [u'Death at a Funeral',
#   u'(2010)',
#   u'/title/tt1321509/',
#   u'Users rated this 5.6/10 (33,584 votes) - click stars to rate',
#   u'5.6',
#   u'A funeral ceremony turns into a debacle of exposed family secrets and misplaced bodies.',
#   u'Neil LaBute',
#   u'Chris Rock, Martin Lawrence, Keith David',
#   u'Comedy',
#   u'R',
#   u'92 mins.'],
#  [u'You Again',
#   u'(2010)',
#   u'/title/tt1414382/',
#   u'Users rated this 5.8/10 (38,616 votes) - click stars to rate',
#   u'5.8',
#   u"When a young woman realizes her brother is about to marry the girl who bullied her in high school, she sets out to expose the fianc\xc3\xa9e's true colors.",
#   u'Andy Fickman',
#   u'Kristen Bell, Odette Annable, Sigourney Weaver',
#   u'Comedy | Romance',
#   u'PG',
#   u'105 mins.'],
#  [u'Edge of Darkness',
#   u'(2010)',
#   u'/title/tt1226273/',
#   u'Users rated this 6.6/10 (71,516 votes) - click stars to rate',
#   u'6.6',
# ...
#   u'Jonah Salander',
#   u'Adam Butcher, Nikki Reed, Meaghan Martin',
#   u'Drama',
#   u'',
#   u''],
#  [u'Charge Over You',
#   u'(2010)',
#   u'/title/tt1762246/',
#   u'Users rated this 6.5/10 (51 votes) - click stars to rate',
#   u'6.5',
#   u'When Sarah meets Mike, everything she thought she knew about the world is turned upside down.',
#   u'Regardt Steenekamp',
#   u'Danya Cox, Dominic Deutscher, James E. Lee',
#   u'Drama | Thriller',
#   u'',
#   u'85 mins.'],
#  [u'Skinning',
#   u'(2010)',
#   u'/title/tt1129437/',
#   u'Users rated this 6.4/10 (3,263 votes) - click stars to rate',
#   u'6.4',
#   u'Life is sometimes rude game: one mistake can buy you ticket to hell.',
#   u'Stevan Filipovic',
#   u'Nikola Rakocevic, Viktor Savic, Natasa Tapuskovic',
#   u'Action | Crime | Drama',
#   u'',
#   u'98 mins.'],
#  [u'Ye Maaya Chesave',
#   u'(2010)',
#   u'/title/tt1602585/',
#   u'Users rated this 7.7/10 (1,262 votes) - click stars to rate',
#   u'7.7',
#   u'Karthik finishes engineering school and aspires to become a filmmaker. His friend Krishna takes him...',
#   u'Gautham Menon',
#   u'Naga Chaitanya Akkineni, Samantha Ruth Prabhu, Krishnudu',
#   u'Romance',
#   u'PG_13',
#   u''],
#  [u'The Clink of Ice',
#   u'(2010)',
#   u'/title/tt1517214/',
#   u'Users rated this 6.2/10 (1,627 votes) - click stars to rate',
#   u'6.2',
#   u'An alcoholic writer is visited by an incarnation of his cancer.',
#   u'Bertrand Blier',
#   u'Jean Dujardin, Albert Dupontel, Anne Alvaro',
#   u'Comedy | Drama',
#   u'',
#   u'87 mins.'],
#  [u'Tender Son: The Frankenstein Project',
#   u'(2010)',
#   u'/title/tt1527049/',
#   u'Users rated this 5.7/10 (405 votes) - click stars to rate',
#   u'5.7',
#   u'A boy returns home from the institution where he grew up, but finds he is not welcome there. He fights to win the love of his family until matters escalate shockingly.',
#   u'Korn\xc3\xa9l Mundrucz\xc3\xb3',
#   u'Rudolf Frecska, Lili Monori, Korn\xc3\xa9l Mundrucz\xc3\xb3',
#   u'Drama',
#   u'',
#   u'109 mins.'],
#  [u'Pop',
#   u'(2010)',
#   u'/title/tt1506452/',
#   u'Users rated this 7.1/10 (850 votes) - click stars to rate',
#   u'7.1',
#   u'Father Alexander is trying to maintain peaceful life for his church amidst the Nazi occupation during WWII.',
#   u'Vladimir Khotinenko',
#   u'Sergey Makovetskiy, Nina Usatova, Elizaveta Arzamasova',
#   u'Drama | History | War',
#   u'',
#   u'130 mins.'],
#  [u'Godkiller: Walk Among Us',
#   u'(2010)',
#   u'/title/tt1384961/',
#   u'Users rated this 5.3/10 (336 votes) - click stars to rate',
#   u'5.3',
#   u"About a 16-year-old boy's odyssey through a post-nuke wasteland as he searches for a new heart to save his dying sister.",
#   u'Matt Pizzolo',
#   u'Danielle Harris, Lance Henriksen, Davey Havok',
#   u'Animation | Sci-Fi',
#   u'',
#   u'73 mins.'],
#  [u'The Ascent',
#   u'(2010)',
#   u'/title/tt1303680/',
#   u'Users rated this 3.6/10 (188 votes) - click stars to rate',
#   u'3.6',
#   u"Mountain guide, Emily Wilks, is forced to lead a group of men up the perilous Devil's Peak. But leading the group up Devil's Peak is just a stalling tactic until Emily reveals her own dark secret.",
#   u'S.J. Creazzo',
#   u'Josie Davis, William McNamara, Martin Kove',
#   u'Action | Drama | Thriller',
#   u'',
#   u''],
#  [u'Sirwi\xf1akuy',
#   u'(2010)',
#   u'/title/tt1621947/',
#   u'Users rated this 5.5/10 (17 votes) - click stars to rate',
#   u'5.5',
#   u'The story of an obsessive relationship between a young French woman and an older Bolivian man. Their unusual romance, like the country in which they live, is transforming, sometimes violent and difficult to understand.',
#   u'Amy Hesketh',
#   u'Veronica Paintoux, Jac Avila, Erix Antoine',
#   u'Drama | Romance',
#   u'',
#   u'111 mins.'],
#  [u'Infection: The Invasion Begins',
#   u'(2010)',
#   u'/title/tt1386583/',
#   u'Users rated this 2.4/10 (363 votes) - click stars to rate',
#   u'2.4',
#   u'A mystery surrounds a small town that was attacked on September 9, 2009. Now sixty years later, the last survivor...',
#   u'Howard Wexler',
#   u'Kelly Pendygraft, Alice Amter, Terry Becker',
#   u'Horror | Sci-Fi | Thriller',
#   u'',
#   u'95 mins.'],
#  [u'The Servant',
#   u'(2010)',
#   u'/title/tt1905059/',
#   u'Users rated this 6.8/10 (337 votes) - click stars to rate',
#   u'6.8',
#   u'A servant falls in love with a girl whom his master also desires. Although the girl loves the servant, she also longs to improve her station in life.',
#   u'Dae-woo Kim',
#   u'Yeo-jeong Jo, Ju-hyuk Kim, Dal-su Oh',
#   u'Drama',
#   u'',
#   u'124 mins.'],
#  [u'Paper Birds',
#   u'(2010)',
#   u'/title/tt1360822/',
#   u'Users rated this 7.0/10 (514 votes) - click stars to rate',
#   u'7.0',
#   u'The lives of a comics and artists group in the hard times after of Spanish Civil War.',
#   u'Emilio Arag\xc3\xb3n',
#   u'Imanol Arias, Llu\xc3\xads Homar, Roger Pr\xc3\xadncep',
#   u'Comedy | Drama',
#   u'',
#   u'122 mins.'],
#  [u'Release',
#   u'(2010)',
#   u'/title/tt1456603/',
#   u'Users rated this 5.1/10 (441 votes) - click stars to rate',
#   u'5.1',
#   u'Father Jack is imprisoned for a crime that he has committed. The inmates suspect him of paedophilia and begin to persuade his teenage cellmate of this. His true crime is confessed to a prison guard with whom Jack has fallen in love.',
#   u'Darren Flaxstone, Christian Martin',
#   u'Daniel Brocklebank, Garry Summers, Bernie Hodges',
#   u'Drama',
#   u'R',
#   u'87 mins.'],
#  [u'No Problem',
#   u'(2010)',
#   u'/title/tt1431122/',
#   u'Users rated this 3.8/10 (1,023 votes) - click stars to rate',
#   u'3.8',
#   u'Bank robbers, diamond thieves, the homicide of a minister, a hyper wife are just some of the challenges faced by a bumbling senior police officer.',
#   u'Anees Bazmee',
#   u'Kangana Ranaut, Anil Kapoor, Sanjay Dutt',
#   u'Action | Comedy | Crime | Drama',
#   u'',
#   u''],
#  [u'Truth About Men',
#   u'(2010)',
#   u'/title/tt1539325/',
#   u'Users rated this 6.8/10 (934 votes) - click stars to rate',
#   u'6.8',
#   u'',
#   u'Nikolaj Arcel',
#   u'Thure Lindhardt, Tuva Novotny, Rosalinde Mynster',
#   u'Comedy | Drama',
#   u'',
#   u'91 mins.'],
#  [u'Mirch',
#   u'(2010)',
#   u'/title/tt1388903/',
#   u'Users rated this 6.6/10 (668 votes) - click stars to rate',
#   u'6.6',
#   u'A story-writer attempts to convince a producer to accept four erotic stories from the Panchtantra.',
#   u'Vinay Shukla',
#   u'Arunoday Singh, Boman Irani, Ila Arun',
#   u'Comedy | Drama | Fantasy',
#   u'',
#   u'105 mins.'],
#  [u'Priest of Evil',
#   u'(2010)',
#   u'/title/tt1604577/',
#   u'Users rated this 6.0/10 (1,265 votes) - click stars to rate',
#   u'6.0',
#   u'Detective Sergeant Timo Harjunp\xc3\x83\xc2\xa4\xc3\x83\xc2\xa4 of the Helsinki Violent Crimes Unit is an honest and conscientious...',
#   u'Olli Saarela',
#   u'Peter Franz\xc3\xa9n, Irina Bj\xc3\xb6rklund, Sampo Sarkola',
#   u'Mystery | Thriller',
#   u'',
#   u'106 mins.'],
#  [u'Naruto Shipp\xfbden: The Lost Tower',
#   u'(2010)',
#   u'/title/tt1703048/',
#   u'Users rated this 6.9/10 (769 votes) - click stars to rate',
#   u'6.9',
#   u'Our hero Naruto is caught in special chakra that propels him into the past. He finds himself in the City of Loran. As he encounters strange things, can he save the future with the past?',
#   u'Masahiko Murata',
#   u'Junko Takeuchi, Chie Nakamura, Satoshi Hino',
#   u'Animation | Action | Adventure',
#   u'',
#   u''],
#  [u'Killer Bitch',
#   u'(2010)',
#   u'/title/tt1624391/',
#   u'Users rated this 1.5/10 (416 votes) - click stars to rate',
#   u'1.5',
#   u'A woman is forced into a deadly game in which she has to kill five people or all her friends and family will be butchered.',
#   u'Liam Galvin',
#   u'Yvette Rowland, Alex Reid, Robin Reid',
#   u'Thriller',
#   u'',
#   u'92 mins.'],
#  [u'Cyrano Agency',
#   u'(2010)',
#   u'/title/tt1786668/',
#   u'Users rated this 6.7/10 (806 votes) - click stars to rate',
#   u'6.7',
#   u"The Cyrano Agency is a dating agency which helps people who can't date to have a love life. The agency...",
#   u'Hyun-seok Kim',
#   u'Tae-woong Eom, Min-jung Lee, Daniel Choi',
#   u'Comedy | Romance',
#   u'',
#   u'119 mins.'],
#  [u'The Dinner Club',
#   u'(2010)',
#   u'/title/tt1625134/',
#   u'Users rated this 5.0/10 (1,346 votes) - click stars to rate',
#   u'5.0',
#   u'Karen (32) and Michel (36) move with their daughter to an exclusive residential area. She soon finds...',
#   u'Robert Jan Westdijk',
#   u'Bracha van Doesburgh, Thom Hoffman, Halina Reijn',
#   u'Thriller',
#   u'',
#   u'94 mins.'],
#  [u'Kooky',
#   u'(2010)',
#   u'/title/tt1630603/',
#   u'Users rated this 7.4/10 (828 votes) - click stars to rate',
#   u'7.4',
#   u'Young Ondra has asthma and so his mom throws away his favorite toy: a musty old stuffed bear named Kooky...',
#   u'Jan Sver\xc3\xa1k',
#   u'Zdenek Sver\xc3\xa1k, Ondrej Sver\xc3\xa1k, Jir\xc3\xad Mach\xc3\xa1cek',
#   u'Comedy | Family | Fantasy',
#   u'',
#   u'95 mins.'],
#  [u'The Joy',
#   u'(2010)',
#   u'/title/tt1646957/',
#   u'Users rated this 5.2/10 (68 votes) - click stars to rate',
#   u'5.2',
#   u'A tale about youth and courage this film tells the story of Luiza,16 year old, who is just tired of hearing about the end of the world...',
#   u'Felipe Bragan\xc3\xa7a, Marina Meliande',
#   u'Clara Barbieri, C\xc3\xa9sar Cardadeiro, Flora Dias',
#   u'Drama',
#   u'',
#   u'106 mins.'],
#  [u'Perfect Combination',
#   u'(2010)',
#   u'/title/tt1431133/',
#   u'Users rated this 3.8/10 (249 votes) - click stars to rate',
#   u'3.8',
#   u'Rick (Christian Keyes, Madea Goes to Jail) has got it all except a steady woman.',
#   u'Trey Haley',
#   u'Christian Keyes, Tiffany Hines, Angell Conwell',
#   u'Comedy | Romance',
#   u'R',
#   u''],
#  [u'Phoonk 2',
#   u'(2010)',
#   u'/title/tt1612611/',
#   u'Users rated this 3.3/10 (364 votes) - click stars to rate',
#   u'3.3',
#   u'While on vacation, children and their father are terrorized by their mother and wife respectively.',
#   u'Milind Gadagkar',
#   u'Sudeep, Amruta Khanvilkar, Ahsaas Channa',
#   u'Drama | Horror | Mystery | Thriller',
#   u'PG_13',
#   u'110 mins.'],
#  [u'The Blonde with Bare Breasts',
#   u'(2010)',
#   u'/title/tt1298831/',
#   u'Users rated this 5.9/10 (431 votes) - click stars to rate',
#   u'5.9',
#   u"The two brothers Julien (Nicolas Duvauchelle) and Louis (Steve Le Roi) work on their father's steel barge...",
#   u'Manuel Pradal',
#   u'Vahina Giocante, Nicolas Duvauchelle, Steve Le Roi',
#   u'Adventure | Drama | Romance',
#   u'',
#   u'100 mins.'],
#  [u'Blessed and Cursed',
#   u'(2010)',
#   u'/title/tt1592247/',
#   u'Users rated this 5.0/10 (190 votes) - click stars to rate',
#   u'5.0',
#   u'',
#   u'Joel Kapity',
#   u"Kierra 'Kiki' Sheard, Deitrick Haddon, Loren Harper",
#   u'Drama',
#   u'',
#   u''],
#  [u'Honey',
#   u'(2010)',
#   u'/title/tt1571724/',
#   u'Users rated this 7.2/10 (4,953 votes) - click stars to rate',
#   u'7.2',
#   u'The quiet life of a boy and his family is endangered when his father does not return home from his work collecting honey in the forest.',
#   u'Semih Kaplanoglu',
#   u'Bora Altas, Erdal Besik\xc3\xa7ioglu, T\xc3\xbclin \xc3\x96zen',
#   u'Drama',
#   u'',
#   u'103 mins.'],
#  [u'Pok\xe9mon: Zoroark: Master of Illusions',
#   u'(2010)',
#   u'/title/tt1690470/',
#   u'Users rated this 6.2/10 (568 votes) - click stars to rate',
#   u'6.2',
#   u'',
#   u'Kunihiko Yuyama',
#   u'Ikue Ohtani, Sean Schemmel, Sarah Natochenny',
#   u'Animation | Family | Fantasy',
#   u'NOT_RATED',
#   u'96 mins.'],
#  [u'An Acrid Yarn',
#   u'(2010)',
#   u'/title/tt1409734/',
#   u'Users rated this 3.6/10 (99 votes) - click stars to rate',
#   u'3.6',
#   u'Based on real events in a small town where the pastor takes advantage of his female flock.',
#   u'Ike Duncan, Tony Roberts',
#   u'John Blackstone, Bettina Brown, Russell Quinn Cummings',
#   u'Thriller',
#   u'',
#   u''],
#  [u'Dreamworks How to Train Your Dragon Legends',
#   u'(2010)',
#   u'/title/tt2542490/',
#   u'Users rated this 7.6/10 (256 votes) - click stars to rate',
#   u'7.6',
#   u'Prepare for high-flying adventures with Hiccup, Toothless and the rest of the Dragon Trainers. Meet new dragons, learn the secrets of the legendary Boneknapper and see what is in store for the holidays on the festive island of Berk.',
#   u'Tom Owens',
#   u'Jay Baruchel, Gerard Butler',
#   u'',
#   u'',
#   u'57 mins.'],
#  [u'Cold Sweat',
#   u'(2010)',
#   u'/title/tt1668212/',
#   u'Users rated this 5.0/10 (646 votes) - click stars to rate',
#   u'5.0',
#   u'Rom\xc3\xa1n and his friend Ali seek out his girlfriend Jackie in a dangerous zone in a suburb in Buenos Aires...',
#   u'Adri\xc3\xa1n Garc\xc3\xada Bogliano',
#   u'Facundo Espinosa, Marina Glezer, Camila Velasco',
#   u'Horror | Thriller',
#   u'',
#   u'90 mins.'],
#  [u"Housewife's Afternoon Delight",
#   u'(2010)',
#   u'/title/tt1577795/',
#   u'Users rated this 4.9/10 (102 votes) - click stars to rate',
#   u'4.9',
#   u'Sayaka is a housewife living in an apartment complex. Her husband Yuji is always busy with work and they rarely have communication...',
#   u'Shun Nakahara',
#   u'Sakiko Takao, Masaki Miura, Masashi End\xc3\xb4',
#   u'Drama',
#   u'',
#   u'70 mins.'],
#  [u'On the Path',
#   u'(2010)',
#   u'/title/tt1156531/',
#   u'Users rated this 7.0/10 (1,356 votes) - click stars to rate',
#   u'7.0',
#   u'From Bosnia/Herzegovina: Amar finds a new job working with a community of Muslims. This affects his relationship with his girlfriend Luna as his beliefs begin to change.',
#   u'Jasmila Zbanic',
#   u'Zrinka Cvitesic, Leon Lucev, Ermin Bravo',
#   u'Drama',
#   u'',
#   u'100 mins.'],
#  [u'Groupie',
#   u'(2010)',
#   u'/title/tt1422653/',
#   u'Users rated this 3.5/10 (316 votes) - click stars to rate',
#   u'3.5',
#   u'When a mysterious groupie joins legendary cursed band, "The Dark Knights", a series of unexplained murders derails their comeback tour.',
#   u'Mark L. Lester',
#   u'Taryn Manning, Hal Ozsan, Eric Roberts',
#   u'Crime | Mystery | Thriller',
#   u'',
#   u'90 mins.'],
#  [u'Bold Native',
#   u'(2010)',
#   u'/title/tt1328908/',
#   u'Users rated this 7.2/10 (432 votes) - click stars to rate',
#   u'7.2',
#   u'Charlie Cranehill, an animal liberator wanted for domestic terrorism, emerges from the underground to coordinate a nationwide action as his estranged CEO father tries to find him before the FBI does.',
#   u'Denis Hennelly',
#   u'Joaquin Pastor, Randolph Mantooth, Sheila Vand',
#   u'Action | Adventure | Comedy | Crime | Drama',
#   u'R',
#   u'105 mins.'],
#  [u'Among Wolves',
#   u'(2010)',
#   u'/title/tt1417582/',
#   u'Users rated this 6.8/10 (621 votes) - click stars to rate',
#   u'6.8',
#   u'A child who lived only with wolves for 12 years.',
#   u'Gerardo Olivares',
#   u'Juan Jos\xc3\xa9 Ballesta, Sancho Gracia, Manuel Camacho',
#   u'Drama',
#   u'',
#   u'113 mins.'],
#  [u'Groupies bleiben nicht zum Fr\xfchst\xfcck',
#   u'(2010)',
#   u'/title/tt1620466/',
#   u'Users rated this 6.6/10 (1,235 votes) - click stars to rate',
#   u'6.6',
#   u"Lila, a girl who returns to Berlin after being abroad for a year, meets Chris. She falls in love with him, but what she doesn't know is that Chris is a famous rock star with many fans chasing him around, including her little sister.",
#   u'Marc Rothemund',
#   u'Anna Fischer, Kostja Ullmann, Inka Friedrich',
#   u'Comedy | Romance',
#   u'',
#   u'103 mins.'],
#  [u'Te presento a Laura',
#   u'(2010)',
#   u'/title/tt1684928/',
#   u'Users rated this 5.9/10 (449 votes) - click stars to rate',
#   u'5.9',
#   u'Young lady that goes by multiple names pursues ways of relieving her guilt from her dark past.',
#   u'Fez Noriega',
#   u'Martha Higareda, Kuno Becker, Adriana Barraza',
#   u'Comedy | Romance',
#   u'',
#   u'90 mins.'],
#  [u'Queen of the Lot',
#   u'(2010)',
#   u'/title/tt1342122/',
#   u'Users rated this 5.2/10 (73 votes) - click stars to rate',
#   u'5.2',
#   u"An electronic ankle bracelet and being under house arrest aren't about to stop up-and-coming actress...",
#   u'Henry Jaglom',
#   u'Tanna Frederick, Noah Wyle, Christopher Rydell',
#   u'Comedy | Drama',
#   u'R',
#   u'120 mins.'],
#  [u'Dark Metropolis',
#   u'(2010)',
#   u'/title/tt1825735/',
#   u'Users rated this 2.3/10 (288 votes) - click stars to rate',
#   u'2.3',
#   u'Mankind has lost a 300-year war against a genetically enhanced race that man created, abused and finally tortured...',
#   u'Stewart St. John',
#   u'Bailey Chase, Eric Scott Woods, Virginia Agcayab',
#   u'Fantasy | Sci-Fi',
#   u'',
#   u'97 mins.'],
#  ...]

# %%
for movie in page:
    imdb = 'http://www.imdb.com'
    movie_id = str(movie[2]) 
    movie_url = imdb + movie_id
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-19d07d4195c6> in <module>()
#       3     for movie in page:
#       4         imdb = 'http://www.imdb.com'
# ----> 5         movie_id = str(movie[2])
#       6         movie_url = imdb + movie_id
#
# KeyboardInterrupt:

# %%
with open('movie_info5.p', 'r') as picklefile:
    fi = pickle.load(picklefile)

# %%
fi["The Matrix Reloaded"]
# Out:
# {'budget': 150000000,
#  'date': '15 May 2003',
#  'genre': ['Action', 'Sci-Fi', 'sequel'],
#  'keywords': ['oracle',
#   'prophecy',
#   'car motorcycle chase',
#   'stylized violence',
#   'one against many',
#   'bullet dodging',
#   'flash forward',
#   'dystopia',
#   'man versus machine',
#   'virtual reality',
#   'parallel world',
#   'sex scene',
#   'computer virus',
#   'underground rave',
#   'cyberpunk',
#   'chosen one',
#   'alternative reality',
#   'gun fu',
#   'kung fu',
#   'rebel',
#   'sentinel',
#   'battle',
#   'dream',
#   'death',
#   'mission',
#   'precognition',
#   'fate',
#   'agent',
#   'box office hit',
#   'making a key',
#   'blood splatter',
#   'year 2003',
#   'same actor playing two characters simultaneously on screen',
#   'same actor playing two characters',
#   'actor playing multiple roles',
#   'pvc',
#   'three word title',
#   'street shootout',
#   '2000s',
#   'distant future',
#   'false reality',
#   '2200s',
#   '23rd century',
#   'christ allegory',
#   'rescue',
#   'nightstick',
#   'action heroine',
#   'heroine',
#   'violence',
#   'ambush',
#   'showdown',
#   'explosion',
#   'duel',
#   'wire fu',
#   'hand to hand combat',
#   'combat',
#   'beretta',
#   'disarming someone',
#   'fighting',
#   'fistfight',
#   'brawl',
#   'kissing while having sex',
#   'knife fight',
#   'sai',
#   'chase',
#   'axe fight',
#   'war against machines',
#   'opening action scene',
#   'semiautomatic pistol',
#   'pistol',
#   'tough girl',
#   'tough guy',
#   'warrior',
#   'action hero',
#   'hero',
#   'hacking',
#   'brain in a vat',
#   'exploding motorcycle',
#   'second part',
#   'shooting out a window',
#   'premonition',
#   'multiple perspectives',
#   'future',
#   'twin',
#   'surrealism',
#   'post apocalypse',
#   'existentialism',
#   'cell phone',
#   'technology gone amok',
#   'dreadlocks',
#   'woman with dark glasses',
#   'tight dress',
#   'man with dark glasses',
#   'star died before release',
#   'cult film',
#   'one man army',
#   'shot back to back',
#   'altered version of studio logo',
#   'science runs amok',
#   'paranoia',
#   'fighting the system',
#   'apocalypse',
#   'no opening credits',
#   'airplane',
#   'no ending',
#   'utopia quest',
#   'shot to death',
#   'part of trilogy',
#   'elevator',
#   'desert eagle',
#   'stabbed in the head',
#   'shot in the forehead',
#   'shot in the arm',
#   'tommy gun',
#   'telekinesis',
#   'outrunning explosion',
#   'impalement',
#   'axe',
#   'imax version',
#   'electro magnetic pulse',
#   'truck',
#   'temple',
#   'subterranean city',
#   'shooting',
#   'resurrection',
#   'restroom',
#   'refugee',
#   'premarital sex',
#   'male nudity',
#   'lucky charm',
#   'locksmith',
#   'injection',
#   'hallway',
#   'ghost',
#   'fight',
#   'female nudity',
#   'falling from height',
#   'faith',
#   'drone',
#   'disciple',
#   'computer engineer',
#   'choice',
#   'car accident',
#   'cake',
#   'assassin',
#   'staircase',
#   'eighteen wheeler',
#   'blood',
#   'obscene finger gesture',
#   'superhero',
#   'sequel mentioned during end credits',
#   'restaurant',
#   'religion',
#   'rave',
#   'power failure',
#   'motorcycle',
#   'morphing',
#   'messiah',
#   'key',
#   'human versus computer',
#   'freeway',
#   'flying',
#   'exploding car',
#   'artificial intelligence',
#   'simulated reality',
#   'blockbuster',
#   'philosophy',
#   'motorcycle chase',
#   'katana sword',
#   'ducati',
#   'car chase',
#   'cadillac',
#   'body landing on a car',
#   'martial arts',
#   'destiny',
#   'sequel',
#   'surprise ending'],
#  'opening': 91774413,
#  'screens': '363'}
